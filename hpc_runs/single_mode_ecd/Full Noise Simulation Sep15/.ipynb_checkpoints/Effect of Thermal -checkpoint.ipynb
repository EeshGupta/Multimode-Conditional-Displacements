# %%
# To find ECD Control

import sys 
sys.path.append('C:\\Users\\Eesh Gupta\\Documents\\RU Research\\Chakram')

# %%
import numpy as np
from qutip import *
from ECD_batch_optimizerV1 import BatchOptimizer
import matplotlib.pyplot as plt
# Out:
# Need tf version 2.3.0 or later. Using tensorflow version: 2.7.0

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#The target oscillator state.
N =10
Fock = 1
psi_i = tensor(basis(2,0), basis(N,0)) # initial state
psi_t = tensor(basis(2,0), basis(N,Fock)) #target state

# %%
#Optimization of ECD Circuit parameters (betas, phis, and thetas)
#the optimization options
opt_params = {
'N_blocks' : 4, #circuit depth
'N_multistart' : 200, #Batch size (number of circuit optimizations to run in parallel)
'epochs' : 200, #number of epochs before termination
'epoch_size' : 10, #number of adam steps per epoch
'learning_rate' : 0.01, #adam learning rate
'term_fid' : 0.995, #terminal fidelitiy
'dfid_stop' : 1e-6, #stop if dfid between two epochs is smaller than this number
'beta_scale' : 3.0, #maximum |beta| for random initialization
'initial_states' : [psi_i], #qubit tensor oscillator, start in |g> |0>
'target_states' : [psi_t], #end in |e> |target>.
'name' : 'Fock %d' % Fock, #name for printing and saving
'filename' : None, #if no filename specified, results will be saved in this folder under 'name.h5'
}


#note: optimizer includes pi pulse in every ECD step. However, final ECD step is implemented 
#in experiment as a displacement since the qubit and oscillator should be disentangled at this point.
#So, we ask the optimizer to end in |e> |target> instead of |g>|target>.

# %% [markdown]
# #### Filename for angles to be stored

# %%
#create optimization object. 
#initial params will be randomized upon creation
opt = BatchOptimizer(**opt_params)

#print optimization info. 
opt.print_info()
# Out:
# None
# Tensor("alphas:0", shape=(1, 200), dtype=complex64)
# Tensor("alphas:0", shape=(4, 200), dtype=complex64)
# optimization_type: state transfer
# N_multistart: 200
# N_blocks: 4
# term_fid: 0.995
# dfid_stop: 1e-06
# no_CD_end: False
# learning_rate: 0.01
# epoch_size: 10
# epochs: 200
# beta_scale: 3.0
# alpha_scale: 1.0
# theta_scale: 3.141592653589793
# use_displacements: False
# use_phase: False
# name: Fock 1
# comment:
# user_angles: None
# N_cav: 10
# filename: Fock 1.h5
#
# Best circuit parameters found:
# betas:         [ 2.36028-0.92448j -1.46259+2.05279j -0.28724+0.62874j -0.19249+0.36479j]
# alphas:        [0.+0.j]
# phis (deg):    [   0.        28.67689  -74.8104  -123.22092]
# thetas (deg):  [ 138.77104 -158.3586  -108.591   -109.11087]
# Max Fidelity:  0.362978

# %%
#run optimizer.
opt.optimize()
# Out:
# Start time: 2022-09-22 13:58:55
#  Epoch: 28 / 200 Max Fid: 0.981403 Avg Fid: 0.809602 Max dFid: 0.092022 Avg dFid: 0.002923 Elapsed time: 0:00:14.418738 Remaing time: 0:01:28.572250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0df2e72ed479> in <module>
#       1 #run optimizer.
# ----> 2 opt.optimize()
#
# ~\Documents\RU Research\Chakram\Multimode-Conditional-Displacements\hpc_runs\single_mode_ecd\Full Noise Simulation Sep15\ECD_batch_optimizerV1.py in optimize(self, do_prints)
#     739                     new_loss = loss_fun(new_fids)
#     740                     dloss_dvar = tape.gradient(new_loss, variables)
# --> 741                 optimizer.apply_gradients(zip(dloss_dvar, variables))
#     742             dfids = new_fids - fids
#     743             fids = new_fids
#
# ~\anaconda\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     663             f"strategy={strategy}.")
#     664
# --> 665       apply_state = self._prepare(var_list)
#     666       if experimental_aggregate_gradients:
#     667         grads_and_vars = self._transform_unaggregated_gradients(grads_and_vars)
#
# ~\anaconda\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in _prepare(self, var_list)
#     947       apply_state[(var_device, var_dtype)] = {}
#     948       with tf.device(var_device):
# --> 949         self._prepare_local(var_device, var_dtype, apply_state)
#     950
#     951     return apply_state
#
# ~\anaconda\lib\site-packages\keras\optimizer_v2\adam.py in _prepare_local(self, var_device, var_dtype, apply_state)
#     125     super(Adam, self)._prepare_local(var_device, var_dtype, apply_state)
#     126
# --> 127     local_step = tf.cast(self.iterations + 1, var_dtype)
#     128     beta_1_t = tf.identity(self._get_hyper('beta_1', var_dtype))
#     129     beta_2_t = tf.identity(self._get_hyper('beta_2', var_dtype))
#
# ~\anaconda\lib\site-packages\tensorflow\python\ops\variables.py in _run_op(a, *args, **kwargs)
#    1076     def _run_op(a, *args, **kwargs):
#    1077       # pylint: disable=protected-access
# -> 1078       return tensor_oper(a.value(), *args, **kwargs)
#    1079
#    1080     functools.update_wrapper(_run_op, tensor_oper)
#
# ~\anaconda\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda\lib\site-packages\tensorflow\python\ops\math_ops.py in binary_op_wrapper(x, y)
#    1381         #   r_binary_op_wrapper use different force_same_dtype values.
#    1382         x, y = maybe_promote_tensors(x, y, force_same_dtype=False)
# -> 1383         return func(x, y, name=name)
#    1384       except (TypeError, ValueError) as e:
#    1385         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~\anaconda\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda\lib\site-packages\tensorflow\python\ops\math_ops.py in _add_dispatch(x, y, name)
#    1735     return gen_math_ops.add(x, y, name=name)
#    1736   else:
# -> 1737     return gen_math_ops.add_v2(x, y, name=name)
#    1738
#    1739
#
# ~\anaconda\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in add_v2(x, y, name)
#     459   if tld.is_eager:
#     460     try:
# --> 461       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     462         _ctx, "AddV2", name, x, y)
#     463       return _result
#
# KeyboardInterrupt:

# %%
#can print info, including the best circuit found.
opt.print_info()
# Out:
# optimization_type: state transfer
# N_multistart: 200
# N_blocks: 4
# term_fid: 0.995
# dfid_stop: 1e-06
# no_CD_end: False
# learning_rate: 0.01
# epoch_size: 10
# epochs: 200
# beta_scale: 3.0
# alpha_scale: 1.0
# theta_scale: 3.141592653589793
# use_displacements: False
# use_phase: False
# name: Fock 1
# comment:
# user_angles: None
# N_cav: 10
# filename: Fock 1.h5
#
# Best circuit parameters found:
# betas:         [-1.21951+0.98334j -0.63591-0.78865j  0.50924-0.41063j -0.00003+0.00001j]
# alphas:        [0.+0.j]
# phis (deg):    [  0.       89.99885 -89.99509  -0.00495]
# thetas (deg):  [-89.99918  89.99989  89.99836 -90.00189]
# Max Fidelity:  0.981403

# %%
angles_filename = 'g0g1opt_angles.txt'
opt.save_angles(filename = angles_filename)

# %% [markdown]
# # Get Pulses

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
from class_description.Simulation_Classes_Single_ModeV4 import *
# Classes: ecd_pulse_single_mode to get pulses
#          , qutip_sim_single_mode to simulate on qutip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9501df33002f> in <module>
#       1 import sys
#       2 sys.path.append('../')
# ----> 3 from class_description.Simulation_Classes_Single_ModeV4 import *
#       4 # Classes: ecd_pulse_single_mode to get pulses
#       5 #          , qutip_sim_single_mode to simulate on qutip
#
# ~\Documents\RU Research\Chakram\Multimode-Conditional-Displacements\hpc_runs\single_mode_ecd\class_description\Simulation_Classes_Single_ModeV4.py in <module>
#     175 from qutip import *
#     176
# --> 177 class qutip_sim_single_mode:
#     178
#     179     def __init__(self, n_q, n_c, chi = None,
#
# ~\Documents\RU Research\Chakram\Multimode-Conditional-Displacements\hpc_runs\single_mode_ecd\class_description\Simulation_Classes_Single_ModeV4.py in qutip_sim_single_mode()
#     262         return None
#     263
# --> 264     def add_qubit_relaxation(self, T1 = self.T1qubit):
#     265         '''
#     266         qubit relaxation (T1 in nanoseconds)
#
# NameError: name 'self' is not defined

# %%
pulse_sim = ecd_pulse_single_mode(param_file = angles_filename,
                                 kappa = 1/(2e+6))   #T1 = 2ms

# %%
pulse_sim.get_pulses()
# Out:
# Modified method: Cond Disp Circuit
# Modified conditional displacement called
# ---------------------------
# Final Displacement: 1.5655614678036835
# Modified conditional displacement called
# C:\Users\Eesh Gupta\anaconda\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------
# Final Displacement: 1.0143061001279021
# Modified conditional displacement called
# ---------------------------
# Final Displacement: 0.6538248081750188
# Modified conditional displacement called
# ---------------------------
# Final Displacement: 0.0007465984111575732

# %%
pulse_sim.plot_pulses()

# %% [markdown]
# # Qutip Simulation

# %%
initial = psi_i
target = psi_t

# %%
#Only ECD term
print('Only ECD term in Qutip')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.me_solve(initial = initial)
ecd_fid = qutip_sim.get_fidelity(target)
print(ecd_fid)


print('Now adding qubit-mode bare coupling')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_bare_qubit_mode_coupling()
qutip_sim.me_solve(initial = initial)
qm_fid = qutip_sim.get_fidelity(target)
print(qm_fid)

print('Now adding Stark Shifts')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_stark_shift()
qutip_sim.me_solve(initial = initial)
ss_fid = qutip_sim.get_fidelity(target)
print(ss_fid)

print('Now adding Transmon Relaxation')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_qubit_relaxation(T1 = 30e+3)
qutip_sim.me_solve(initial = initial)
tr_fid = qutip_sim.get_fidelity(target)
print(tr_fid)

print('Now adding Transmon Dephasing')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_qubit_dephasing(T1 = 30e+3, Techo = 50e+3)
qutip_sim.me_solve(initial = initial)
tp_fid = qutip_sim.get_fidelity(target)
print(tp_fid)

print('Now Adding Cavity Relaxation')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_cavity_relaxation(T1 = 2e+6)
qutip_sim.me_solve(initial = initial)
cr_fid = qutip_sim.get_fidelity(target)
print(cr_fid)

print('Now Adding Cavity Dephasing')
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_cavity_dephasing(T1 = 2e+6, Techo = 3e+6)
qutip_sim.me_solve(initial = initial)
cp_fid = qutip_sim.get_fidelity(target)
print(cp_fid)
# Out:
# Only ECD term in Qutip
# change
# (0.9809538423409097+0j)
# Now adding qubit-mode bare coupling
# change
# (0.9805848787910598+0j)
# Now adding Stark Shifts
# change
# (0.9798900946317973+0j)
# Now adding Transmon Relaxation
# change
# 0.946489891146326
# Now adding Transmon Dephasing
# change
# 0.9607578476105937
# Now Adding Cavity Relaxation
# change
# 0.9618796063430624
# Now Adding Cavity Dephasing
# change
# 0.9623104109993486

# %%
qutip_sim = qutip_sim_single_mode(n_q = 2, n_c = N,
                               alpha = pulse_sim.alpha,
                               qubit_pulse = pulse_sim.qubit_dac_pulse_GHz,
                               save_states = False)
qutip_sim.add_cavity_dephasing(T1 = 2e+6, Techo = 3e+6)
qutip_sim.me_solve(initial = initial)

# %%
np.shape(qutip_sim.output.states[-1])
# Out:
# (20, 20)

# %%
type(qutip_sim.output.states[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-6db919577ffa> in <module>
# ----> 1 type(qutip_sim.output.states[-1])
#
# AttributeError: 'qutip_sim_single_mode' object has no attribute 'output'

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
conditions = ['Batch Optimizer', 'Qutip: only ecd', 
              'bare_qubit_mode_coupling','Stark Shift',
               'transmon_relax','transmon_dephasing',
             'cavity relaxation', 'cavity_dephasing']
x_pos = np.arange(len(conditions))
bars = [opt.best_fidelity(), ecd_fid, qm_fid, ss_fid,
       np.sqrt(tr_fid), np.sqrt(tp_fid), np.sqrt(cr_fid), np.sqrt(cp_fid)]
bars_inv = [1- i for i in bars]

fig, ax = plt.subplots(figsize = (8,6))
ax.barh(conditions, bars_inv, align='center')
ax.set_xlabel('$1-\mathcal{F}$')
#ax.set_xticks(x_pos)
ax.set_yticklabels(conditions, fontsize = 15)
ax.set_title('Qutip Noise Simulation of g0 -> g1')
ax.xaxis.grid(True)
#plt.yticks(range(len(conditions)), conditions, rotation = 90)
# Out:
# <ipython-input-90-e53dcb8d97eb>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(conditions, fontsize = 15)

# %%
conditions = ['Only ecd', 
              'bare_qubit_mode_coupling','Stark Shift',
               'transmon_relax','transmon_dephasing',
             'cavity relaxation', 'cavity_dephasing']
x_pos = np.arange(len(conditions))
bars = [ ecd_fid, qm_fid, ss_fid,
       np.sqrt(tr_fid), np.sqrt(tp_fid), np.sqrt(cr_fid), np.sqrt(cp_fid)]
bars = [opt.best_fidelity() - i for i in bars]
#bars_inv = [1- i for i in bars]

fig, ax = plt.subplots(figsize = (8,6))
ax.barh(conditions, bars, align='center')
ax.set_xlabel('$1-\mathcal{F}_{Opt}$')
#ax.set_xticks(x_pos)
ax.set_yticklabels(conditions, fontsize = 15)
ax.set_title('Qutip Noise Simulation of g0 -> g1')
ax.xaxis.grid(True)
#plt.yticks(range(len(conditions)), conditions, rotation = 90)
# Out:
# <ipython-input-100-41e46397413f>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(conditions, fontsize = 15)
