# %%
# To find ECD Control

import sys 
sys.path.append('C:\\Users\\Eesh Gupta\\Documents\\RU Research\\Chakram')

# %%
import numpy as np
from qutip import *
from DECD_paramV1 import FixedBatchOptimizer as BatchOptimizer
import matplotlib.pyplot as plt

# %%
from OptimizationAnalysis import OptimizationAnalysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#Modes Truncation
N1 = 5
N2 = 5

# %%
#The target oscillator state.
#Initial oscillator state.
Fock1 = 0
Fock2= 0
psi_i1 = basis(N1,Fock1) #initial state
psi_i2 = basis(N2,Fock2)
initial = tensor(basis(2,0), psi_i1, psi_i2)

#Target
Fock1 = 1
Fock2= 1
psi_t1 = basis(N1,Fock1) #target state
psi_t2 = basis(N2,Fock2)
target = tensor(basis(2, 0), psi_t1, psi_t2)

# %%
#Optimization of ECD Circuit parameters (betas, phis, and thetas)
#the optimization options
opt_params = {
    'N_blocks' : 2, #circuit depth
    'N_multistart' : 10, #Batch size (number of circuit optimizations to run in parallel)
    'epochs' : 10, #number of epochs before termination
    'epoch_size' : 10, #number of adam steps per epoch
    'learning_rate' : 0.01, #adam learning rate
    'term_fid' : 0.995, #terminal fidelitiy
    'dfid_stop' : 1e-6, #stop if dfid between two epochs is smaller than this number
    'beta_scale' : 3.0, #maximum |beta| for random initialization
    'gamma_scale' : 3.0, #maximum |gamma| for random initialization
    'N_cav1': N1, #number of levels in mode 1
    'N_cav2': N2, #number of levels in mode 2
    'initial_states' : [initial], #qubit tensor oscillator, start in |g> |0>
    'target_states' : [target], #end in |e> |target>.
    #"initial_params": init_params,
    'name' : 'Data/Fock_test_11_1', #name for printing and saving
    'filename' : None, #if no filename specified, results will be saved in this folder under 'name.h5'
    }


#note: optimizer includes pi pulse in every ECD step. However, final ECD step is implemented 
#in experiment as a displacement since the qubit and oscillator should be disentangled at this point.
#So, we ask the optimizer to end in |e> |target> instead of |g>|target>.

# %% [markdown]
# #### Filename for angles to be stored

# %%
#create optimization object. 
#initial params will be randomized upon creation
opt = BatchOptimizer(**opt_params)

#print optimization info. 
opt.print_info()
# Out:
# None
# Fixed construct needed matrices called
# optimization_type: state transfer
# N_multistart: 10
# N_blocks: 2
# term_fid: 0.995
# dfid_stop: 1e-06
# no_CD_end: False
# learning_rate: 0.01
# epoch_size: 10
# epochs: 10
# beta_scale: 3.0
# gamma_scale: 3.0
# alpha1_scale: 1.0
# alpha2_scale: 1.0
# theta_scale: 3.141592653589793
# use_etas: False
# use_displacements: False
# use_phase: False
# name: Data/Fock_test_11_1
# comment:
# initial_params: None
# N_cav1: 5
# N_cav2: 5
# filename: Data/Fock_test_11_1.h5
#
# Best circuit parameters found:
# betas:         [1.38364-0.1295j  0.54986-1.97223j]
# gammas:         [ 0.04839+1.49333j -0.78417-2.39013j]
# alphas1:        [0.+0.j]
# alphas2:        [0.+0.j]
# phis (deg):    [ 0.      41.44656]
# etas (deg):    [89.99999 89.99999]
# thetas (deg):  [  0.42609 -51.26277]
# Max Fidelity:  0.057892

# %%
#run optimizer.
opt.optimize()
# Out:
# Start time: 2023-01-16 09:16:26
#  Epoch: 10 / 10 Max Fid: 0.228386 Avg Fid: 0.155630 Max dFid: 0.019163 Avg dFid: 0.005570 Elapsed time: 0:00:04.693040 Remaing time: 0:00:00493805
#
# Optimization stopped.  Reached maximum number of epochs. Terminal fidelity not reached.
#
# optimization_type: state transfer
# N_multistart: 10
# N_blocks: 2
# term_fid: 0.995
# dfid_stop: 1e-06
# no_CD_end: False
# learning_rate: 0.01
# epoch_size: 10
# epochs: 10
# beta_scale: 3.0
# gamma_scale: 3.0
# alpha1_scale: 1.0
# alpha2_scale: 1.0
# theta_scale: 3.141592653589793
# use_etas: False
# use_displacements: False
# use_phase: False
# name: Data/Fock_test_11_1
# comment:
# initial_params: None
# N_cav1: 5
# N_cav2: 5
# filename: Data/Fock_test_11_1.h5
#
# Best circuit parameters found:
# betas:         [0.98176+0.12059j 0.11788-1.79919j]
# gammas:         [-0.3406 +1.97808j -2.55009-2.25638j]
# alphas1:        [0.+0.j]
# alphas2:        [0.+0.j]
# phis (deg):    [ 0.      -3.33892]
# etas (deg):    [89.99999 89.99999]
# thetas (deg):  [-0.95797 -2.681  ]
# Max Fidelity:  0.230417
#
#
# all data saved as: Data/Fock_test_11_1.h5
# termination reason: epochs
# optimization timestamp (start time): 2023-01-16 09:16:26
# timestamp (end time): 2023-01-16 09:16:31
# elapsed time: 0:00:04.701103
# Time per epoch (epoch size = 10): 0:00:00.470110
# Time per Adam step (N_multistart = 10, N_cav1 = 5, N_cav2 = 5): 0:00:00.047011
#
# ============================================================
# '2023-01-16 09:16:26'

# %%
filename
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0ee53525f0e4> in <module>
# ----> 1 filename
#
# NameError: name 'filename' is not defined

# %%
filename = opt.filename
analysis = OptimizationAnalysis(filename)

# %%
analysis.print_info()
# Out:
# N_blocks: 2
# N_cav1: 5
# N_cav2: 5
# N_multistart: 10
# alpha1_scale: 1.0
# alpha2_scale: 1.0
# beta_scale: 3.0
# comment:
# dfid_stop: 1e-06
# elapsed_time_s: 4.693039655685425
# epoch_size: 10
# epochs: 10
# gamma_scale: 3.0
# initial_params: []
# learning_rate: 0.01
# name: Data/Fock_test_11_1
# no_CD_end: False
# optimization_type: state transfer
# term_fid: 0.995
# termination_reason: epochs
# theta_scale: 3.141592653589793
# use_displacements: False
# use_etas: False
# use_phase: False
# filename: Data/Fock_test_11_1.h5
#
# Best circuit parameters found:
# betas:         [0.98176+0.12059j 0.11788-1.79919j]
# gammas:         [-0.3406 +1.97808j -2.55009-2.25638j]
# alphas1:        [0.+0.j]
# alphas2:        [0.+0.j]
# phis (deg):    [ 0.      -3.33892]
# thetas (deg):  [-0.95797 -2.681  ]
# Max Fidelity:  0.228386

# %%
analysis.plot_fidelities()

# %%
opt.parameters.items()
for parameter, value in opt.parameters.items():
    print(parameter)
    print(value)
    print('------')
# Out:
# optimization_type
# state transfer
# ------
# N_multistart
# 2
# ------
# N_blocks
# 2
# ------
# term_fid
# 0.995
# ------
# dfid_stop
# 1e-06
# ------
# no_CD_end
# False
# ------
# learning_rate
# 0.01
# ------
# epoch_size
# 20
# ------
# epochs
# 10
# ------
# beta_scale
# 3.0
# ------
# gamma_scale
# 3.0
# ------
# alpha1_scale
# 1.0
# ------
# alpha2_scale
# 1.0
# ------
# theta_scale
# 3.141592653589793
# ------
# use_etas
# False
# ------
# use_displacements
# False
# ------
# use_phase
# False
# ------
# name
# Data/Fock_test_11
# ------
# comment
#
# ------
# initial_params
# None
# ------
# N_cav1
# 5
# ------
# N_cav2
# 5
# ------

# %%
#can print info, including the best circuit found.
opt.print_info()
# Out:
# optimization_type: state transfer
# N_multistart: 2
# N_blocks: 2
# term_fid: 0.995
# dfid_stop: 1e-06
# no_CD_end: False
# learning_rate: 0.01
# epoch_size: 20
# epochs: 10
# beta_scale: 3.0
# gamma_scale: 3.0
# alpha1_scale: 1.0
# alpha2_scale: 1.0
# theta_scale: 3.141592653589793
# use_etas: False
# use_displacements: False
# use_phase: False
# name: ECD_control
# comment:
# initial_params: None
# N_cav1: 10
# N_cav2: 10
# filename: ECD_control.h5
#
# Best circuit parameters found:
# betas:         [-0.22724-1.50095j  1.28741-0.19488j]
# gammas:         [-0.56921+0.42973j  1.12533+1.49402j]
# alphas1:        [0.+0.j]
# alphas2:        [0.+0.j]
# phis (deg):    [ 0.     38.6132]
# etas (deg):    [89.99999 89.99999]
# thetas (deg):  [-100.4647   100.34767]
# Max Fidelity:  0.135336

# %%
angles_filename = 'test_opt_angles.txt'
opt.save_angles(filename = angles_filename)

# %% [markdown]
# # Get Pulses

# %%
from Simulation_Classes_Two_ModeV2 import *
# Classes: ecd_pulse_single_mode to get pulses
#          , qutip_sim_single_mode to simulate on qutip

# %%
T1_mode1 = 2e+6 #2ms
T1_mode2 = 2e+6 #2ms

pulse_sim = ecd_pulse_two_mode(param_file = angles_filename,
                              kappa1 = 1/T1_mode1,
                              kappa2 = 1/T1_mode2)

# %%
pulse_sim.get_pulses()
# Out:
# ---------------------------------------------------
# final displacement is 1.5177153032967357
# C:\Users\Eesh Gupta\anaconda\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------
# final displacement is 0.713212847699548
# ---------------------------------------------------
# final displacement is 1.3020713450028283
# ---------------------------------------------------
# final displacement is 1.870419609263129

# %%
pulse_sim.plot_pulses()

# %% [markdown]
# # Qutip Simulation

# %%
qutip_sim  = qutip_sim_two_mode(n_q = 2, n_c1 = 10, n_c2 = 10, alpha1 = pulse_sim.alpha1, alpha2 = pulse_sim.alpha2, qubit_pulse = pulse_sim.qubit_dac_pulse_GHz)

# %%
# Add various terms 

# to the hamiltonian 
qutip_sim.add_bare_qubit_mode_coupling() # chi/2 adag a sigmaz
qutip_sim.add_mode_mode_coupling()
qutip_sim.add_stark_shift() # chi/2 alpha^2 sigmaz

# to the collapse operators (noise)
qutip_sim.add_qubit_relaxation(T1 = 30e+3) # T1 in nanoseconds
qutip_sim.add_qubit_dephasing(T1 = 30e+3, Techo = 50e+3) # T1, T2 in nanoseconds
qutip_sim.add_cavity_relaxation(T1_mode1 = 2e+6, T1_mode2 = 2e+6) # assumes kappa correction to equation of motion in pulses
qutip_sim.add_cavity_dephasing(T1_mode1 = 2e+6, Techo_mode1 = 3e+6, T1_mode2 = 2e+6, Techo_mode2 = 3e+6) # T1, T2 from photon blockade paper

# %%
qutip_sim.me_solve(initial = initial)  #initial state by default is g0

# %%
qutip_sim.plot_populations()
# Out:
# Loaded list object.

# %%
qutip_sim.get_fidelity(target)
# Out:
# 0.008804368859147663
