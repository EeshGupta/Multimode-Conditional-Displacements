# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
filename = "Noise_sim_one_by_one__15_level_aug_4"
df = pd.read_csv(filename)
df
# Out:
#     exact fidelity  bo_fidelity  \
# 0              NaN          NaN
# 1         0.995586     0.995598
# 2         0.995586     0.995598
# 3         0.996460     0.996470
# 4         0.994936     0.995629
# 5         0.995886     0.995833
# 6         0.996191     0.996193
# 7         0.996768     0.996779
# 8         0.996423     0.996423
# 9         0.996415     0.996425
# 10        0.996539     0.996526
# 11        0.995410     0.995419
# 12        0.996151     0.996892
#
#                                                 betas  \
# 0                                                 NaN
# 1   [-0.00262321-0.00144306j  0.02715145-0.0185476...
# 2   [-0.00262321-0.00144306j  0.02715145-0.0185476...
# 3   [-6.4737914e-04-3.2210814e-05j -5.2747920e-01+...
# 4   [ 1.0140339e-03+5.3937244e-04j -4.4833508e-04-...
# 5   [ 6.5347767e-06-1.30088590e-04j  2.0591020e-03...
# 6   [ 6.5717466e-02+1.5812736j  -1.1736141e-02+0.0...
# 7   [ 1.38473530e-03+1.6311259e-03j  1.09282150e+0...
# 8   [-0.02452667-2.7897577e-03j -0.00146851+1.7478...
# 9   [ 1.4479039e-03-4.1262887e-04j  3.3884450e-04-...
# 10  [ 0.01475754-0.04110372j  0.4100612 -0.2312351...
# 11  [-0.13434817-1.1718981j   0.06487343-0.0059511...
# 12  [-5.3234910e-01+0.40944073j  1.7488065e-01+0.3...
#
#                                                gammas  \
# 0                                                 NaN
# 1   [-0.22359522-4.9973166e-01j -0.7231863 +1.4162...
# 2   [-0.22359522-4.9973166e-01j -0.7231863 +1.4162...
# 3   [ 5.0107450e-01+1.6034484e-02j -1.5052351e+00-...
# 4   [ 2.636092  +0.4190833j   0.01244382-0.432337j...
# 5   [-3.8990060e-01-3.9146677e-01j  5.7316244e-01-...
# 6   [ 1.418391  +0.24241747j  0.33849597-0.9158984...
# 7   [ 9.3426320e-02-4.8979080e-01j  3.3189622e-01+...
# 8   [-3.7821588e-01-2.5588945e-01j -6.1016450e-01+...
# 9   [-0.4419903 +0.3685562j  -0.5735252 -0.605279j...
# 10  [-0.43818113+0.2351073j  -2.1519425 +1.3530631...
# 11  [ 0.3952284 +1.0193292j   0.39807162+0.1077477...
# 12  [-1.0163183 +0.4193015j  -3.339142  -1.2887808...
#
#                                                  phis  \
# 0                                                 NaN
# 1   [ 0.         1.3961155  1.2453349  1.0953438 -...
# 2   [ 0.         1.3961155  1.2453349  1.0953438 -...
# 3   [ 0.         -1.5745307  -0.7655482   1.881175...
# 4   [ 0.        -0.7320552  1.9630716 -2.370027   ...
# 5   [ 0.         -1.5533143  -1.5631359  -1.597816...
# 6   [ 0.          0.81113863 -2.1159046  -1.300121...
# 7   [ 0.          1.5340307  -2.4499028  -0.181198...
# 8   [ 0.          1.5692036   1.5720084  -1.343168...
# 9   [ 0.          1.5909874   1.6046488   1.625607...
# 10  [ 0.         -1.567324    1.4665563   1.599829...
# 11  [ 0.         -0.25606656  1.6486723   1.125031...
# 12  [ 0.         -2.6540499  -3.0331106   1.722667...
#
#                                                thetas  only ecd  \
# 0                                                 NaN       NaN
# 1   [-1.5561874   2.275472    1.7466791   2.030403...  0.966536
# 2   [-1.5561874   2.275472    1.7466791   2.030403...  0.966536
# 3   [ 1.5732338 -1.2030032 -3.1294155  3.1376164 -...  0.978428
# 4   [-0.0271492  1.5207536 -1.6562961  2.018657  -...  0.975053
# 5   [ 1.5757606e+00 -1.1407130e+00  1.5744059e+00 ...  0.974244
# 6   [ 3.136113   -1.5799026   0.99619174  0.772885...  0.991382
# 7   [ 1.5795605  -1.1847471   3.134495    1.818692...  0.981544
# 8   [-1.5716397   1.3233197  -2.0805616   0.003912...  0.987179
# 9   [-1.5605228  -2.0086124  -1.5044947   0.602578...  0.992799
# 10  [-1.5563223  -1.123174   -0.00695944 -3.125749...  0.957976
# 11  [-0.02907538  1.589442    1.7153823   1.757087...  0.951823
# 12  [-3.1135798 -1.6277546 -3.1389937  1.9205401 -...  0.986340
#
#     bare_qubit_mode_coupling  Stark Shift  Mode Coupling  transmon_relax  \
# 0                        NaN          NaN            NaN             NaN
# 1                   0.968844     0.924391       0.966429    0.000000e+00
# 2                   0.968844     0.924391       0.966429    2.399757e-20
# 3                   0.980985     0.970801       0.977964    1.987570e-19
# 4                   0.974456     0.964664       0.975224    1.017130e-19
# 5                   0.967694     0.956901       0.973919    2.691986e-20
# 6                   0.988607     0.993112       0.991543    2.924106e-19
# 7                   0.973725     0.989234       0.981419    3.111519e-16
# 8                   0.987697     0.982570       0.986811    9.831067e-19
# 9                   0.993258     1.012000       0.992428    2.385469e-20
# 10                  0.969507     0.960364       0.957139    5.807630e-19
# 11                  0.956071     0.940265       0.951656    1.227546e-21
# 12                  0.920232     0.955296       0.985874    5.861503e-17
#
#     transmon_dephasing
# 0                  NaN
# 1             0.000000
# 2             0.000478
# 3             0.000727
# 4             0.000222
# 5             0.000377
# 6             0.000862
# 7             0.000554
# 8             0.000552
# 9             0.000732
# 10            0.000423
# 11            0.000474
# 12            0.000222

# %%
df = df.drop(0)
df
# Out:
#     exact fidelity  bo_fidelity  \
# 1         0.995586     0.995598
# 2         0.995586     0.995598
# 3         0.996460     0.996470
# 4         0.994936     0.995629
# 5         0.995886     0.995833
# 6         0.996191     0.996193
# 7         0.996768     0.996779
# 8         0.996423     0.996423
# 9         0.996415     0.996425
# 10        0.996539     0.996526
# 11        0.995410     0.995419
# 12        0.996151     0.996892
#
#                                                 betas  \
# 1   [-0.00262321-0.00144306j  0.02715145-0.0185476...
# 2   [-0.00262321-0.00144306j  0.02715145-0.0185476...
# 3   [-6.4737914e-04-3.2210814e-05j -5.2747920e-01+...
# 4   [ 1.0140339e-03+5.3937244e-04j -4.4833508e-04-...
# 5   [ 6.5347767e-06-1.30088590e-04j  2.0591020e-03...
# 6   [ 6.5717466e-02+1.5812736j  -1.1736141e-02+0.0...
# 7   [ 1.38473530e-03+1.6311259e-03j  1.09282150e+0...
# 8   [-0.02452667-2.7897577e-03j -0.00146851+1.7478...
# 9   [ 1.4479039e-03-4.1262887e-04j  3.3884450e-04-...
# 10  [ 0.01475754-0.04110372j  0.4100612 -0.2312351...
# 11  [-0.13434817-1.1718981j   0.06487343-0.0059511...
# 12  [-5.3234910e-01+0.40944073j  1.7488065e-01+0.3...
#
#                                                gammas  \
# 1   [-0.22359522-4.9973166e-01j -0.7231863 +1.4162...
# 2   [-0.22359522-4.9973166e-01j -0.7231863 +1.4162...
# 3   [ 5.0107450e-01+1.6034484e-02j -1.5052351e+00-...
# 4   [ 2.636092  +0.4190833j   0.01244382-0.432337j...
# 5   [-3.8990060e-01-3.9146677e-01j  5.7316244e-01-...
# 6   [ 1.418391  +0.24241747j  0.33849597-0.9158984...
# 7   [ 9.3426320e-02-4.8979080e-01j  3.3189622e-01+...
# 8   [-3.7821588e-01-2.5588945e-01j -6.1016450e-01+...
# 9   [-0.4419903 +0.3685562j  -0.5735252 -0.605279j...
# 10  [-0.43818113+0.2351073j  -2.1519425 +1.3530631...
# 11  [ 0.3952284 +1.0193292j   0.39807162+0.1077477...
# 12  [-1.0163183 +0.4193015j  -3.339142  -1.2887808...
#
#                                                  phis  \
# 1   [ 0.         1.3961155  1.2453349  1.0953438 -...
# 2   [ 0.         1.3961155  1.2453349  1.0953438 -...
# 3   [ 0.         -1.5745307  -0.7655482   1.881175...
# 4   [ 0.        -0.7320552  1.9630716 -2.370027   ...
# 5   [ 0.         -1.5533143  -1.5631359  -1.597816...
# 6   [ 0.          0.81113863 -2.1159046  -1.300121...
# 7   [ 0.          1.5340307  -2.4499028  -0.181198...
# 8   [ 0.          1.5692036   1.5720084  -1.343168...
# 9   [ 0.          1.5909874   1.6046488   1.625607...
# 10  [ 0.         -1.567324    1.4665563   1.599829...
# 11  [ 0.         -0.25606656  1.6486723   1.125031...
# 12  [ 0.         -2.6540499  -3.0331106   1.722667...
#
#                                                thetas  only ecd  \
# 1   [-1.5561874   2.275472    1.7466791   2.030403...  0.966536
# 2   [-1.5561874   2.275472    1.7466791   2.030403...  0.966536
# 3   [ 1.5732338 -1.2030032 -3.1294155  3.1376164 -...  0.978428
# 4   [-0.0271492  1.5207536 -1.6562961  2.018657  -...  0.975053
# 5   [ 1.5757606e+00 -1.1407130e+00  1.5744059e+00 ...  0.974244
# 6   [ 3.136113   -1.5799026   0.99619174  0.772885...  0.991382
# 7   [ 1.5795605  -1.1847471   3.134495    1.818692...  0.981544
# 8   [-1.5716397   1.3233197  -2.0805616   0.003912...  0.987179
# 9   [-1.5605228  -2.0086124  -1.5044947   0.602578...  0.992799
# 10  [-1.5563223  -1.123174   -0.00695944 -3.125749...  0.957976
# 11  [-0.02907538  1.589442    1.7153823   1.757087...  0.951823
# 12  [-3.1135798 -1.6277546 -3.1389937  1.9205401 -...  0.986340
#
#     bare_qubit_mode_coupling  Stark Shift  Mode Coupling  transmon_relax  \
# 1                   0.968844     0.924391       0.966429    0.000000e+00
# 2                   0.968844     0.924391       0.966429    2.399757e-20
# 3                   0.980985     0.970801       0.977964    1.987570e-19
# 4                   0.974456     0.964664       0.975224    1.017130e-19
# 5                   0.967694     0.956901       0.973919    2.691986e-20
# 6                   0.988607     0.993112       0.991543    2.924106e-19
# 7                   0.973725     0.989234       0.981419    3.111519e-16
# 8                   0.987697     0.982570       0.986811    9.831067e-19
# 9                   0.993258     1.012000       0.992428    2.385469e-20
# 10                  0.969507     0.960364       0.957139    5.807630e-19
# 11                  0.956071     0.940265       0.951656    1.227546e-21
# 12                  0.920232     0.955296       0.985874    5.861503e-17
#
#     transmon_dephasing
# 1             0.000000
# 2             0.000478
# 3             0.000727
# 4             0.000222
# 5             0.000377
# 6             0.000862
# 7             0.000554
# 8             0.000552
# 9             0.000732
# 10            0.000423
# 11            0.000474
# 12            0.000222

# %%
conditions = ['bo_fidelity', 'only ecd', 'bare_qubit_mode_coupling','Stark Shift', 'Mode Coupling', 'transmon_relax','transmon_dephasing']
#x_pos = np.arange(len(conditions))
bars = []
bars_err = []
for i in range(len(conditions)):
    listy = list(df[conditions[i]]) 
    bars.append(1 - np.mean(listy))
    bars_err.append(np.std(listy))

fig, ax = plt.subplots(figsize = (8,6))
ax.bar(conditions, bars, yerr=bars_err, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('$1-\mathcal{F}$')
ax.set_xticks(x_pos)
ax.set_xticklabels(conditions, fontsize = 15)
ax.set_title('Qutip Noise Simulation of g01 -> g10')
ax.yaxis.grid(True)
plt.xticks(range(len(conditions)), conditions, rotation = 90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb5b2558130>,
#   <matplotlib.axis.XTick at 0x7fb5b2558100>,
#   <matplotlib.axis.XTick at 0x7fb5b2560fd0>,
#   <matplotlib.axis.XTick at 0x7fb5b250f370>,
#   <matplotlib.axis.XTick at 0x7fb5b250fac0>,
#   <matplotlib.axis.XTick at 0x7fb5b2516250>,
#   <matplotlib.axis.XTick at 0x7fb5b250fbb0>],
#  [Text(0, 0, 'bo_fidelity'),
#   Text(1, 0, 'only ecd'),
#   Text(2, 0, 'bare_qubit_mode_coupling'),
#   Text(3, 0, 'Stark Shift'),
#   Text(4, 0, 'Mode Coupling'),
#   Text(5, 0, 'transmon_relax'),
#   Text(6, 0, 'transmon_dephasing')])

# %%
conditions = ['bo_fidelity', 'only ecd', 'bare_qubit_mode_coupling','Stark Shift', 'Mode Coupling']#, 'transmon_relax','transmon_dephasing']
#x_pos = np.arange(len(conditions))
bars = []
bars_err = []
for i in range(len(conditions)):
    listy = list(df[conditions[i]]) 
    bars.append(1 - np.mean(listy))
    bars_err.append(np.std(listy))
conditions[-1] = "Mode-Mode Coupling"
fig, ax = plt.subplots(figsize = (8,6))
ax.bar(conditions, bars, yerr=bars_err, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('$1-\mathcal{F}$')
#a#x.set_xticks(x_pos)
ax.set_xticklabels(conditions, fontsize = 15)
ax.set_title('Decoherence free error budget of g01 -> g10')
ax.yaxis.grid(True)
plt.xticks(range(len(conditions)), conditions, rotation = 45)
# Out:
# /tmp/ipykernel_13011/4096408048.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(conditions, fontsize = 15)
# ([<matplotlib.axis.XTick at 0x7fb5b0c20130>,
#   <matplotlib.axis.XTick at 0x7fb5b0bdafa0>,
#   <matplotlib.axis.XTick at 0x7fb5b0b99b80>,
#   <matplotlib.axis.XTick at 0x7fb5b0b46730>,
#   <matplotlib.axis.XTick at 0x7fb5b0b46df0>],
#  [Text(0, 0, 'bo_fidelity'),
#   Text(1, 0, 'only ecd'),
#   Text(2, 0, 'bare_qubit_mode_coupling'),
#   Text(3, 0, 'Stark Shift'),
#   Text(4, 0, 'Mode-Mode Coupling')])
