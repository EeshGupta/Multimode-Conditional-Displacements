# %% [markdown]
# # AIM
#
#  COmponents of qutip various simulation
#
#  1.  ECD Hamiltonian
#  1.5 Bare qubit-mode coupling
#  2. Stark Shift
#
#
# Varying coherence times of ancilla

# %%
import sys 
sys.path.append('C:\\Users\\Eesh Gupta\\Documents\\RU Research\\Chakram')
sys.path.append('C:\\Users\\Eesh Gupta\\Documents\\RU Research\\Chakram\\ECD_control')

# For Prof. Chakram Desktop 
#sys.path.append('C:\\_Lib\\python\\ECD_control')
# sys.path.append('C:\\_Lib\\python')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#from  ECD_control import ECD_optimization  
#from ECD_control import ECD_pulse_construction

import numpy as np
import qutip as qt 
from DECD_param import FixedBatchOptimizer as BatchOptimizer
#from ECD_control.ECD_optimization.batch_optimizer import BatchOptimizer # contains custom initial angles framework
#from ECD_control.ECD_optimization.optimization_analysis import OptimizationAnalysis, OptimizationSweepsAnalysis
import matplotlib.pyplot as plt
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# 2022-08-11 12:39:20.363951: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2494455452923547741
#  xla_global_id: -1]

# %%
#Modes Truncation
N1 = 15
N2 = 15

# %% [markdown]
# ### Batch Optimizer

# %%
#get the params 
import pandas as pd
param_df = pd.read_csv(r'../parameter_datasets/15_mode_10_layers_01_10_Aug5.csv')

# %%
param_df
# Out:
#     exact fidelity  bo_fidelity  \
# 0              NaN          NaN
# 1         0.995586     0.995598
# 2         0.996460     0.996470
# 3         0.994936     0.995629
# 4         0.995886     0.995833
# 5         0.996191     0.996193
# 6         0.996768     0.996779
# 7         0.996423     0.996423
# 8         0.996415     0.996425
# 9         0.996539     0.996526
# 10        0.995410     0.995419
# 11        0.996151     0.996892
# 12        0.996046     0.996057
# 13        0.995514     0.995527
# 14        0.995435     0.995447
# 15        0.995630     0.995640
# 16        0.995647     0.995658
# 17        0.994997     0.994999
# 18        0.996778     0.996790
# 19        0.996108     0.996206
# 20        0.996503     0.996409
#
#                                               betas_r  \
# 0                                                 NaN
# 1   [-0.0026232067, 0.027151449, -0.03374483, -0.6...
# 2   [-0.00064737914, -0.5274792, -0.14209414, 0.38...
# 3   [0.0010140339, -0.00044833508, 0.021753615, 0....
# 4   [6.5347767e-06, 0.002059102, 0.0009163625, -1....
# 5   [0.065717466, -0.011736141, 0.0005303437, 0.00...
# 6   [0.0013847353, 1.0928215, 1.0787609, 1.8399953...
# 7   [-0.024526674, -0.001468513, 0.731406, -0.0014...
# 8   [0.0014479039, 0.0003388445, 0.0047782534, 0.2...
# 9   [0.014757544, 0.4100612, 0.056332387, 0.529517...
# 10  [-0.13434817, 0.064873435, 0.028837385, 0.0974...
# 11  [-0.5323491, 0.17488065, 0.18488207, 0.0004060...
# 12  [0.053415544, 0.03276061, -0.72671664, 0.50738...
# 13  [-0.023599532, 0.12864238, -0.1544991, 1.12238...
# 14  [0.00038583355, 0.010304817, 0.028765421, -0.3...
# 15  [-0.0053952704, -0.011230764, -0.010824246, 0....
# 16  [1.6138869e-05, -0.00058515626, -5.7298028e-05...
# 17  [-0.0058465754, 0.0040344223, 0.0048983083, -0...
# 18  [-0.0091952095, -0.0059313513, 0.03329, -0.986...
# 19  [-0.98479784, -0.08985412, 2.3343237e-05, 0.01...
# 20  [0.97547954, -0.6062471, -0.5060018, 0.1031140...
#
#                                               betas_i  \
# 0                                                 NaN
# 1   [-0.0014430584, -0.018547617, -0.053650122, 1....
# 2   [-3.2210814e-05, 0.4463694, 1.7933315, 1.34824...
# 3   [0.00053937244, -0.0012067384, 0.017490216, -0...
# 4   [-0.00013008859, 0.00048024504, -0.0014477341,...
# 5   [1.5812736, 0.011016973, -0.018761091, 0.01595...
# 6   [0.0016311259, 1.6620002, 1.6679025, -0.058019...
# 7   [-0.0027897577, 0.017478578, 1.059633, -0.0005...
# 8   [-0.00041262887, -0.001409223, -0.004569121, 1...
# 9   [-0.04110372, -0.23123512, -0.26953924, -0.515...
# 10  [-1.1718981, -0.005951176, 0.11952243, 0.74012...
# 11  [0.40944073, 0.33060774, 0.33858046, 0.0015742...
# 12  [0.00043730208, 0.20563652, 0.8263402, 0.54939...
# 13  [0.17487738, 0.06771363, -0.7662739, 0.8559581...
# 14  [0.0044177007, -0.018102003, 0.02179125, 0.699...
# 15  [0.0019077185, 0.005853403, 0.006567984, -0.00...
# 16  [4.1656784e-07, -0.00031808345, 0.00080455537,...
# 17  [0.23586836, -0.0051197396, 0.029050592, 2.101...
# 18  [-0.07670327, -0.015536035, 0.12815379, 0.2302...
# 19  [3.016957, -0.0694348, -1.5636895e-05, -0.4124...
# 20  [-1.8008901, 0.021724977, 0.17548616, -0.18906...
#
#                                              gammas_r  \
# 0                                                 NaN
# 1   [-0.22359522, -0.7231863, 0.68294007, 0.522158...
# 2   [0.5010745, -1.5052351, 0.08454239, 1.7569891,...
# 3   [2.636092, 0.012443824, -0.7358306, 0.40474427...
# 4   [-0.3899006, 0.57316244, -0.7931359, 0.1817324...
# 5   [1.418391, 0.33849597, 0.12522796, -1.0475554,...
# 6   [0.09342632, 0.33189622, 1.0272089, 0.10161271...
# 7   [-0.37821588, -0.6101645, -2.2035275, 1.134002...
# 8   [-0.4419903, -0.5735252, 0.7638508, 0.3190096,...
# 9   [-0.43818113, -2.1519425, 0.21571338, -2.22962...
# 10  [0.3952284, 0.39807162, -0.2416246, -0.4908823...
# 11  [-1.0163183, -3.339142, -3.7376442, 0.5392238,...
# 12  [0.4370692, -0.1796887, -0.7677486, 0.09254911...
# 13  [-0.41124973, 0.16735496, 0.7593758, -0.413105...
# 14  [0.6786639, 0.4678808, -0.71788025, 0.86706346...
# 15  [-0.038381312, -0.6908275, -1.489343, -0.60254...
# 16  [-0.013051703, 0.27022335, 1.1322314, -2.62023...
# 17  [0.23466308, -0.12494462, -0.8728569, -0.25243...
# 18  [0.3223123, -0.2770297, 0.58476394, 1.1769708,...
# 19  [-2.2832534, -0.3146167, -0.5036264, 0.7143837...
# 20  [-0.39721578, -0.3241391, -0.012672152, -0.590...
#
#                                              gammas_i  \
# 0                                                 NaN
# 1   [-0.49973166, 0.14162038, 0.41028225, -1.20223...
# 2   [0.016034484, -0.9608084, -1.6549327, -0.01448...
# 3   [0.4190833, -0.432337, 0.32447094, 0.7893773, ...
# 4   [-0.39146677, -0.55157095, 0.3414926, 1.548996...
# 5   [0.24241747, -0.9158984, 0.6000691, -0.8345659...
# 6   [-0.4897908, 2.0188828, 2.2436624, 1.1113484, ...
# 7   [-0.25588945, 0.4345048, -1.700655, -1.1269199...
# 8   [0.3685562, -0.605279, 0.5171412, -1.6222814, ...
# 9   [0.2351073, 1.3530631, -0.86167055, -0.1734489...
# 10  [1.0193292, 0.10774773, 0.6411945, -0.3488023,...
# 11  [0.4193015, -1.2887808, -1.5735607, -0.4976256...
# 12  [0.21173628, 0.84380805, -0.2304579, 0.4251334...
# 13  [0.14435014, 0.7470328, -0.1817234, 1.2285705,...
# 14  [-0.035015885, 0.6810722, -0.47470486, 0.62539...
# 15  [-0.559946, -0.5464395, -0.47817928, -0.477768...
# 16  [-1.2203062, -0.64830697, -0.34614617, -0.1627...
# 17  [-1.1638896, 0.5317287, -0.15863663, 1.5821569...
# 18  [0.33131698, -2.0219207, 1.368075, -0.02200466...
# 19  [-1.3313614, -0.33219108, 0.56787145, 0.145571...
# 20  [-0.14950015, 1.0128866, 0.6122077, -0.5700663...
#
#                                                  phis  \
# 0                                                 NaN
# 1   [0.0, 1.3961155, 1.2453349, 1.0953438, -2.1847...
# 2   [0.0, -1.5745307, -0.7655482, 1.8811753, 0.579...
# 3   [0.0, -0.7320552, 1.9630716, -2.370027, 1.9950...
# 4   [0.0, -1.5533143, -1.5631359, -1.597816, -1.62...
# 5   [0.0, 0.81113863, -2.1159046, -1.3001214, 0.87...
# 6   [0.0, 1.5340307, -2.4499028, -0.18119884, 3.11...
# 7   [0.0, 1.5692036, 1.5720084, -1.3431681, 2.1121...
# 8   [0.0, 1.5909874, 1.6046488, 1.6256077, 1.60755...
# 9   [0.0, -1.567324, 1.4665563, 1.599829, -1.50532...
# 10  [0.0, -0.25606656, 1.6486723, 1.1250317, 0.792...
# 11  [0.0, -2.6540499, -3.0331106, 1.722667, -1.230...
# 12  [0.0, -1.5717974, -1.5714543, 1.5722821, 1.569...
# 13  [0.0, -1.5606408, 1.6027138, 1.6216185, -1.515...
# 14  [0.0, -1.3452626, 1.9926999, -1.0770557, 0.300...
# 15  [0.0, 1.5325372, 1.73052, 1.9503105, -1.095568...
# 16  [0.0, -1.5783584, -1.5878719, 1.558984, -1.580...
# 17  [0.0, 3.022167, 1.4343798, -0.5085888, -0.5429...
# 18  [0.0, -1.5688759, -2.971778, -1.5651125, 1.595...
# 19  [0.0, 1.098386, -1.1598302, -2.3179443, -0.180...
# 20  [0.0, -3.029816, 0.15482235, -1.901315, -2.061...
#
#                                                thetas
# 0                                                 NaN
# 1   [-1.5561874, 2.275472, 1.7466791, 2.0304034, -...
# 2   [1.5732338, -1.2030032, -3.1294155, 3.1376164,...
# 3   [-0.0271492, 1.5207536, -1.6562961, 2.018657, ...
# 4   [1.5757606, -1.140713, 1.5744059, 2.4605734, 0...
# 5   [3.136113, -1.5799026, 0.99619174, 0.77288556,...
# 6   [1.5795605, -1.1847471, 3.134495, 1.8186929, 0...
# 7   [-1.5716397, 1.3233197, -2.0805616, 0.00391268...
# 8   [-1.5605228, -2.0086124, -1.5044947, 0.6025781...
# 9   [-1.5563223, -1.123174, -0.0069594383, -3.1257...
# 10  [-0.029075384, 1.589442, 1.7153823, 1.757087, ...
# 11  [-3.1135798, -1.6277546, -3.1389937, 1.9205401...
# 12  [-1.5706296, 1.4895356, 1.0034211, 1.6622422, ...
# 13  [1.5928729, 1.4919174, -1.476476, 1.473964, 0....
# 14  [-1.5263152, 2.5195239, -1.5366302, 2.076894, ...
# 15  [-1.6246727, -1.2640513, -3.0303385, -1.404585...
# 16  [1.5699475, 2.536854, 1.9831378, -1.5300605, 0...
# 17  [-0.13555598, -1.4189367, 1.3641584, 1.5468323...
# 18  [-1.5761349, -1.8640035, -0.0040209293, 0.9540...
# 19  [0.0010435581, -1.5815451, -1.9396795, 1.97016...
# 20  [-0.00878191, -1.5924234, -2.9705281, -1.11591...

# %%
# def get_params(n_layers, initial, target): 
#     '''
#     Runs Batch Optimizer to produce a unitary which maps given initial state to final state
    
#     Note: It solves a State Transfer Problem
    
#     Returns parameters beta, gamma, phi and theta as a function of layers
#     '''
    
#     #Optimization of ECD Circuit parameters (betas, phis, and thetas)
#     #the optimization options
#     opt_params = {
#     'N_blocks' : n_layers, #circuit depth
#     'N_multistart' : 10, #Batch size (number of circuit optimizations to run in parallel)
#     'epochs' : 200, #number of epochs before termination
#     'epoch_size' : 20, #number of adam steps per epoch
#     'learning_rate' : 0.01, #adam learning rate
#     'term_fid' : 0.999, #terminal fidelitiy
#     'dfid_stop' : 1e-6, #stop if dfid between two epochs is smaller than this number
#     'beta_scale' : 3.0, #maximum |beta| for random initialization
#     'gamma_scale' : 3.0, #maximum |gamma| for random initialization
#     'N_cav1': N1, #number of levels in mode 1
#     'N_cav2': N2, #number of levels in mode 2
#     'initial_states' : [qt.tensor(qt.basis(2,0),initial)], #qubit tensor oscillator, start in |g> |0>
#     'target_states' : [qt.tensor(qt.basis(2,0), target)], #end in |e> |target>.
#     #"initial_params": init_params,
#     'name' : 'Fock1 %d' % Fock1, #name for printing and saving
#     'filename' : None, #if no filename specified, results will be saved in this folder under 'name.h5'
#     }



#     #note: optimizer includes pi pulse in every ECD step. However, final ECD step is implemented 
#     #in experiment as a displacement since the qubit and oscillator should be disentangled at this point.
#     #So, we ask the optimizer to end in |e> |target> instead of |g>|target>.
    
#     #create optimization object. 
#     #initial params will be randomized upon creation
#     opt = BatchOptimizer(**opt_params)

#     #print optimization info. 
#     opt.print_info()
    
    
#     #run optimizer.
#     #opt.optimize()
    
#     #get optimized param
#     reported_fid = opt.best_circuit()['fidelity']
#     betas = opt.best_circuit()['betas']
#     gammas = opt.best_circuit()['gammas']
#     phis = opt.best_circuit()['phis']
#     thetas = opt.best_circuit()['thetas']

#     return reported_fid, betas, gammas, phis, thetas

# %% [markdown]
# ### Get the Pulses

# %%
#from ECD_control import ECD_optimization
#from ECD_control import ECD_pulse_construction

# from tensorflow.python.client import device_lib
# device_lib.list_local_devices()
from DECD_pulse import *

# %%
def alpha_from_epsilon_nonlinear_finite_difference(
    epsilon_array, delta=0, alpha_init=0 + 0j):
    '''
    These are equations of motion used in cancelling d alpha/dt and cavity drive terms
    '''
    dt = 1
    alpha = np.zeros_like(epsilon_array)
    alpha[0] = alpha_init
    alpha[1] = alpha_init
    for j in range(1, len(epsilon_array) - 1):
        alpha[j + 1] = (
                2*
                 dt
                * (
                    -1j * delta# * alpha[j]
                    #- 2j * Ks * np.abs(alpha[j]) ** 2 * alpha[j]
                    #- (kappa / 2.0) * alpha[j]
                    - 1j * epsilon_array[j]
                )
                + alpha[j - 1])
    return alpha

def alpha_star_from_epsilon_nonlinear_finite_difference(
    epsilon_array, delta=0, alpha_init=0 + 0j):
    dt = 1
    alpha = np.zeros_like(epsilon_array)
    alpha[0] = alpha_init
    alpha[1] = alpha_init
    for j in range(1, len(epsilon_array) - 1):
        alpha[j + 1] = (
                2*
                 dt
                * (
                    1j * delta# * alpha[j]
                    #- 2j * Ks * np.abs(alpha[j]) ** 2 * alpha[j]
                    #- (kappa / 2.0) * alpha[j]
                    + 1j * epsilon_array[j]
                )
                + alpha[j - 1])
    return alpha

# %%
def get_pulses(betas, gammas, phis, thetas):
    '''
    Returns alpha(t) (displacements) and qubit pulse for the Batch Optimizer's generated parameters
    '''
    
    #Our cavity(ies) and qubit. When using pulse construction on the FPGA, these objects can be loaded, and 
    #Here, we are making a "FakeCavity" and a "FakeQubit" with parameters found from experimental calibrations.

    storage1_params = {
            "chi_kHz": -33, #dispersive shift
            "chi_prime_Hz": 0, #second order dispersive shift
            "Ks_Hz": 0, #Kerr correction not yet implemented.
            "epsilon_m_MHz": 400, #largest oscillator drive amplitude in MHz (max|epsilon|)
            "unit_amp": 0.01, #DAC unit amp of gaussian displacement to alpha=1.
            "sigma": 11, #oscillator displacement sigma
            "chop": 4, #oscillator displacement chop (number of stds. to include in gaussian pulse)
        }
    storage2_params = {
            "chi_kHz": -33, #dispersive shift
            "chi_prime_Hz": 0, #second order dispersive shift
            "Ks_Hz": 0, #Kerr correction not yet implemented.
            "epsilon_m_MHz": 400, #largest oscillator drive amplitude in MHz (max|epsilon|)
            "unit_amp": 0.01, #DAC unit amp of gaussian displacement to alpha=1.
            "sigma": 11, #oscillator displacement sigma
            "chop": 4, #oscillator displacement chop (number of stds. to include in gaussian pulse)
        }
    qubit_params = {'unit_amp': 0.5, 'sigma': 6, 'chop': 4} #parameters for qubit pi pulse.

    #calculating conversion between qubit DAC units and MHz (Omega)
    pi = rotate(np.pi, phi=0, sigma=qubit_params['sigma'], chop=qubit_params['chop'], dt=1)
    Omega_m = np.real(np.max(pi))/qubit_params['unit_amp']

    #creating the "Fake storage" and "Fake qubit"
    storage1 = FakeStorage(**storage1_params)
    storage2 = FakeStorage(**storage2_params)
    qubit = FakeQubit(**qubit_params)

    #The maximum displacement used during the ECD gates.
    alpha_CD1 = 30
    alpha_CD2 = 30
    #Small delay to insert between oscillator and qubit pulses
    buffer_time = 4
    
    
    #generating the conditional displacement circuit.
    #set 'chi_prime_correction = True' to correct for linear part of chi'
    #final_disp = True will implement final ECD gate as a displacement
    pulse_dict = conditional_displacement_circuit(betas, gammas, phis, thetas, storage1, storage2, qubit,
                         alpha_CD1, alpha_CD2 ,buffer_time=buffer_time, kerr_correction = False, chi_prime_correction=True, final_disp=True, pad=True)
    cavity1_dac_pulse, cavity2_dac_pulse, qubit_dac_pulse, = pulse_dict['cavity1_dac_pulse'], pulse_dict['cavity2_dac_pulse'], pulse_dict['qubit_dac_pulse']
    
    #Dac units to Ghz conversion

    cavity1_dac_pulse_GHz = (2*np.pi)*(10**(-3))*storage1.epsilon_m_MHz*cavity1_dac_pulse #convert from DAC to Mhz to Ghz
    cavity2_dac_pulse_GHz = (2*np.pi)*(10**(-3))*storage2.epsilon_m_MHz*cavity2_dac_pulse #convert from DAC to Mhz to Ghz
    qubit_dac_pulse_GHz = (2*np.pi)*10**(-3)*qubit.Omega_m_MHz*qubit_dac_pulse #convert from DAC to Mhz to Ghz

    alpha1 = alpha_from_epsilon_nonlinear_finite_difference(
        epsilon_array =cavity1_dac_pulse_GHz , delta=0, alpha_init=0 + 0j)
    alpha1_star = alpha_star_from_epsilon_nonlinear_finite_difference(
        epsilon_array =np.conjugate(cavity1_dac_pulse_GHz) , delta=0, alpha_init=0 + 0j)
    
    alpha2 = alpha_from_epsilon_nonlinear_finite_difference(
        epsilon_array =cavity2_dac_pulse_GHz , delta=0, alpha_init=0 + 0j)
    alpha2_star = alpha_star_from_epsilon_nonlinear_finite_difference(
        epsilon_array =np.conjugate(cavity2_dac_pulse_GHz) , delta=0, alpha_init=0 + 0j)
    
    return alpha1, alpha1_star, alpha2, alpha2_star, qubit_dac_pulse_GHz, storage1_params, storage2_params

# %% [markdown]
# ### Qutip Simulation

# %%
#for time dep hammy
def mult(a,b):
    '''
    Elementwise multiplication of two lists
    '''
    if len(a) != len(b):
        print('Error with mult: lists must be of same length')
        return []
    output = [a[i]*b[i] for i in range(len(a)) ]
    return np.asarray(output) 

# qutip doesn't like complex numbers in parenthesis notation which is default python notation
# z = (a + bi)
# what qutip wants is z = a+ bi
#This is achieved by the np.asarray() function

def dot(state1, state2):
    '''
    finding prob of measure state2 given we have prepared state 1
    '''
    fid = state1.overlap(state2)
    return fid*np.conjugate(fid)

# %%
from qutip import *
from qutip.control import *
from math import *

def get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
                  qubit_dac_pulse_GHz, storage1_params, storage2_params,
                 sim_params, parameters, initial, final):
    '''
    simulation using qutip and return fidelities
    
    sim_params ( a dictionary) turns various terms on and off in full hamiltonaian
    
    parameters : a dictionary containing values of parameters like qubit T1 times, etc.
    '''
    
    T = len(alpha1)
    times = np.linspace(0, T, T) #1ns timesteps
    
    n_c1 = N1  #number of levels in cavity
    n_c2 = N2  #number of levels in cavity
    n_q = 2 #number of levels in qubit

    #N = 1 #target cavity state

    omega_c1  = 5.26 *2*pi   #frequencies in GHz
    omega_c2 = 5.26 *2*pi   #frequencies in GHz
    omega_q = 6.65*2*pi
    #K = -3.7*(10**(-6))*2*pi #cavity nonlinearity

    #photon depenedent number shifts
    chi1 = storage1_params["chi_kHz"]*2*pi*(10**(-6)) #linear
    chi1_ = storage1_params["chi_prime_Hz"]*(10**(-9)) #quadratic
    chi2 = storage2_params["chi_kHz"]*2*pi*(10**(-6)) #linear
    chi2_ = storage2_params["chi_prime_Hz"]*(10**(-9)) #quadratic

    ##mode to mode coupling 
    eta = 1*2*pi*10**(-9)
    
    ## Transmon Relaxation and Dephasing (Data from Fast ECD paper)
    T1 = parameters['ancilla_T1_mu_s']*(10**(3))   # 50 microseconds in nanosecond 
    Techo = 65*(10**(3)) 
    gamma_relax = 1/T1
    gamma_echo = 1/Techo
    gamma_phi = gamma_echo - (gamma_relax/2)
    
    # Creating identity, annhilitation/creation, num operators 
    identity_q = qeye(n_q)
    identity_c = qeye(n_c1)

    a_q = destroy(n_q)
    a_c = destroy(n_c1)

    adag_q = create(n_q)
    adag_c = create(n_c1)

    num_q = num(n_q)
    num_c =  num(n_c1)


    c_ops = [
        sim_params['transmon_relax']*np.sqrt(gamma_relax/2)*tensor(a_q, identity_c, identity_c),
        sim_params['transmon_dephasing']*np.sqrt(gamma_phi)*tensor(num_q, identity_c, identity_c)
    ]

    tlist = times
    
    # Displace Frame hammy
    H0_disp= ( tensor(identity_q, identity_c, identity_c) + # placeholder
        (sim_params['bare_qubit_mode_coupling']*(chi1/2)*tensor(sigmaz(), num_c, identity_c))+  # first mode -qubit
        (sim_params['bare_qubit_mode_coupling']*(chi2/2)*tensor(sigmaz(), identity_c, num_c)) +# 2nd mode - qubit
        (sim_params['Mode Coupling']*(eta)*tensor(identity_q, num_c, num_c) )
        )

    # Preparing coefficients of various time dependent terms in Hamiltonian 
    
    alpha1_sq =np.real( [np.real(i)**2 + np.imag(i)**2 for i in alpha1])
    alpha2_sq =np.real( [np.real(i)**2 + np.imag(i)**2 for i in alpha2])
    alpha1_times_2 = mult(alpha1, alpha2)
    alpha1star_times_2 = mult(alpha1_star, alpha2)

    H = [H0_disp,
         #Qubit drive
        [tensor(a_q, identity_c, identity_c), np.conjugate(qubit_dac_pulse_GHz)], 
         [tensor(adag_q, identity_c, identity_c), qubit_dac_pulse_GHz],

         # Desired Displacement term from qubit-mode1 coupling
         [(chi1/2)*tensor(sigmaz(), a_c, identity_c), alpha1_star],  
         [(chi1/2)*tensor(sigmaz(), adag_c, identity_c), alpha1],

         # Desired Displacement term from qubit-mode2 coupling
         [(chi2/2)*tensor(sigmaz(),  identity_c, a_c), alpha2_star],  
         [(chi2/2)*tensor(sigmaz(), identity_c, adag_c), alpha2],
         
         #Stark Shifts
         [sim_params['Stark Shift']*(chi1/2)*tensor(sigmaz(), identity_c, identity_c), alpha1_sq],
         [sim_params['Stark Shift']*(chi2/2)*tensor(sigmaz(), identity_c, identity_c), alpha2_sq],
        
         # UnDesired Displacement term from mode-mode coupling (no disp^2)

         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, a_c, num_c), alpha1_star],  
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, adag_c, num_c), alpha1],
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, num_c, a_c), alpha2_star],  
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, num_c, adag_c), alpha2],

         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, a_c, a_c), np.conjugate(alpha1_times_2)],  
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, a_c, adag_c), alpha1star_times_2],
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, adag_c, a_c), np.conjugate(alpha1star_times_2)],  
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, adag_c, adag_c), alpha1_times_2],

         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, identity_c,num_c, ), alpha1_sq],
         [sim_params['Mode Coupling']*(eta)*tensor(identity_q, num_c, identity_c), alpha2_sq],
     
        ]
        
        
        
        
    
    print('starting evolution')
    psi0 = tensor(basis(n_q,0), initial)
    opts = Options(store_states=True, store_final_state=True,nsteps = 10000 ,max_step = 10)
    output = mesolve(H, psi0 , times, c_ops, [], options =opts)
    rho = output.states[-1]
    print('finished evolution')
    
    target_g = tensor(basis(n_q,0), target)
    fid1 = dot(target_g, rho)
    
#     target_e = tensor(basis(n_q,1 ), basis(n_c, 1))
#     fid2 = dot(target_e, rho)
    
    return fid1 #, fid2, T

# %%
# sim_params = {'Stark Shift': 0, 'Mode Coupling': 0}  # 0 means false, 1 means true or activates
# ecd_fid = get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
#           qubit_dac_pulse_GHz, storage1_params, storage2_params, 
#                          sim_params)
# ecd_terms.append(ecd_fid)

# %% [markdown]
# ### Calculator (Not Needed)
# Since Batch Optimizer agrees generally with calc

# %%
from qutip import *

# %%
def mod_disp_op(disp, n_q, n_c):
    '''
    Returns displacement operator using baken campbell formula
    '''
    pauli_like_x = (create(n_c) + destroy(n_c))
    pauli_like_y = (1j)*(create(n_c) - destroy(n_c))
    comm = (1/2)*((pauli_like_x*pauli_like_y) - (pauli_like_y*pauli_like_x))
    re = np.real(disp)
    im = np.imag(disp)

    first = (1j*im*pauli_like_x).expm()
    second = (-1j*re*pauli_like_y).expm()
    third = ((im*re)*(-1)*comm).expm()
    return first*second*third

def disp_op(disp, n_q, n_c):
    '''
    Returns displacement operator for specified displacement
    '''
    #disp = normalize_complex(disp)
    exponent = (disp*create(n_c))- (np.conjugate(disp)*destroy(n_c))
    return  exponent.expm()

def cond_disp_op(beta, n_q, n_c1, n_c2,mode, use_mod):
    '''
    Returns cond displacement operator for specified real displacement
    '''
    disp = beta/2
    
    n_c = n_c1 if mode == 1 else n_c2
    
    if use_mod: 
        d = mod_disp_op(disp= disp, n_q = n_q, n_c = n_c) #Baker Campbell Approx
    else: 
        d = disp_op(disp= disp, n_q = n_q, n_c = n_c)
    d_adjoint = d.dag()
    
    if mode == 1: 
        left = tensor(create(n_q), d, qeye(n_c2)) #D(beta/2)|e><g|
        right = tensor(destroy(n_q), d_adjoint, qeye(n_c2)) #D(-beta/2)|g><e|   ...not sure d_adjoint(alpha) = d(-alpha) if use Baker
    
    else: #mode ==2 
        left = tensor(create(n_q), qeye(n_c2), d)
        right = tensor(destroy(n_q),  qeye(n_c2), d_adjoint)
    return left+right

def qubit_rot(phi, theta, n_q, n_c1, n_c2):
    '''
    Returns qubit rotation
    '''
    rot = (np.cos(phi)*sigmax()) + (np.sin(phi)*sigmay())
    exp = (-1.0j)*(theta/2)*(rot)
    return tensor(exp.expm(), qeye(n_c1), qeye(n_c2) )

def normalize_complex(number):
    '''
    Returns radius r of complex number z = r*e^iphi
    '''
    return np.sqrt(number.real**2 + (number .imag**2))

def dot(state1, state2):
    '''
    dotting both states
    '''
    fid = state1.overlap(state2)
    return fid*np.conjugate(fid)
def evolve(initial_state, betas, gammas, phis, thetas, n_q, n_c1, n_c2, use_mod = False):
    '''
    Operates on initial_state with ECD(beta_n)*R(phi_n, theta_n) *...........*ECD(beta_1)*R(phi_1, theta_1)
    '''
    n = len(betas)
    state = initial_state
    for i in range(n):
        beta = betas[i]
        gamma = gammas[i]
        phi = phis[i]
        theta = thetas[i]
        
  
    
        #state = cond_disp_op(gamma, n_q, n_c1,n_c2,mode = 2,use_mod = use_mod)*cond_disp_op(beta, n_q, n_c1,n_c2, mode = 1,use_mod = use_mod)*qubit_rot(phi, theta, n_q, n_c1, n_c2)*state
        state = cond_disp_op(beta, n_q, n_c1,n_c2, mode = 1,use_mod = use_mod)*cond_disp_op(gamma, n_q, n_c1,n_c2,mode = 2,use_mod = use_mod)*qubit_rot(phi, theta, n_q, n_c1, n_c2)*state
           
    return state

# %%
# initial = tensor(basis(2, 0), basis(N1, 0), basis(N2, 0))
# target = tensor(basis(2, 0), basis(N1, 1), basis(N2, 0))
# pi_target = tensor(basis(2, 1), basis(N1, 1), basis(N2, 0))

# %%
def Calculator(betas,gammas, phis, thetas): 
    '''
    Returns fidelity using qutip matrix algebra
    '''
    rho_calc = evolve(tensor(basis(2,0), initial),betas,gammas, phis, thetas,n_q = 2,n_c1 = N1, n_c2 = N2,
                   use_mod = False)
    return dot(tensor(basis(2,0),target), rho_calc)

# %%
#Calculator(betas,gammas, phis, thetas)

# %% [markdown]
# # Main
# Vary conditions, see differences in fidelities

# %%
#Initial oscillator state.
Fock1 = 0
Fock2= 1
psi_i1 = qt.basis(N1,Fock1) #initial state
psi_i2 = qt.basis(N2,Fock2)
initial = qt.tensor(psi_i1, psi_i2)

#Target
Fock1 = 1
Fock2= 0
psi_t1 = qt.basis(N1,Fock1) #target state
psi_t2 = qt.basis(N2,Fock2)
target = qt.tensor(psi_t1, psi_t2)

# %% [markdown]
# Get parameters from a file

# %%
# fname = 'Test_01_10_Aug2.txt'
# b_file = open(fname, "r")
# params = np.loadtxt(b_file)

# betas = np.asarray([complex(params[0][i], params[1][i]) for i in range(len(params[0]))])
# gammas = np.asarray([complex(params[2][i], params[3][i]) for i in range(len(params[0]))])
# phis = params[4]
# thetas = params[5]

# %%
#BO_fid, betas, gammas, phis, thetas = get_params(10, initial, target)

# %%
#Calculator(betas,gammas, phis, thetas)

# %%
#alpha1, alpha1_star, alpha2, alpha2_star, qubit_dac_pulse_GHz, storage1_params, storage2_params = get_pulses(betas, gammas, phis, thetas)

# %%
# sim_params = {'bare_ecd' :0 , 'Stark Shift': 0, 'Mode Coupling': 0, 'transmon_relax': 0,'transmon_dephasing': 0 }  # 0 means false, 1 means true or activates

# #Run the qutip fids
# print('Only ECD term in Qutip')
# ecd_fid = get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
#           qubit_dac_pulse_GHz, storage1_params, storage2_params, 
#                          sim_params, initial, target)

# %%
#ecd_fid

# %%
# sim_params['bare_ecd'] = 1

# ecd_fid = get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
#           qubit_dac_pulse_GHz, storage1_params, storage2_params, 
#                          sim_params, initial, target)
# print(ecd_fid)

# %%
# sim_params = {'Stark Shift': 0, 'Mode Coupling': 0, 'transmon_relax': 0,'transmon_dephasing': 1 }  # 0 means false, 1 means true or activates

# #Run the qutip fids
# print('Only ECD term in Qutip')
# ecd_fid = get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
#           qubit_dac_pulse_GHz, storage1_params, storage2_params, 
#                          sim_params, initial, target)
# print(ecd_fid)

# %%
# sim_params['bare_ecd'] = True

# ecd_fid = get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
#           qubit_dac_pulse_GHz, storage1_params, storage2_params, 
#                          sim_params, initial, target)
# print(ecd_fid)

# %%
sim_params = {'bare_qubit_mode_coupling':0,'Stark Shift': 0, 'Mode Coupling': 0, 'transmon_relax': 0,'transmon_dephasing': 0 }  # 0 means false, 1 means true or activates    
errors = [key for key in sim_params.keys()]
errors
# Out:
# ['bare_qubit_mode_coupling',
#  'Stark Shift',
#  'Mode Coupling',
#  'transmon_relax',
#  'transmon_dephasing']

# %%
columns = ['exact fidelity','bo_fidelity','betas','gammas','phis','thetas',
                                                   'tramsmon_relaxation [50 us, 100 us, ...]']
df = pd.DataFrame([[None for i in range(7)]], columns=columns)

# %%
df
# Out:
#   exact fidelity bo_fidelity betas gammas  phis thetas  \
# 0           None        None  None   None  None   None
#
#   tramsmon_relaxation [50 us, 100 us, ...]
# 0                                     None

# %%
fname = "Noise_sim_one_by_one__15_level_aug_11_transmon_relaxation"
df.to_csv(fname, index=False)

# %%
# mod_param_df = param_df.drop(0)
# mod_param_df

# %%
# def convert_comp_arr_str_to_orig(param_arry):
#     '''
#     pandas screws up np.asarray objects big time by converting them to string
#     this function undoes it (assumes that each element is a complex num)
#     '''
#     new_param_array = []
#     for k in range(len(param_arry)):
#         arry = param_arry[k+1]
#         print(arry)
#         #First get rid of []
#         b = arry.split('[')
#         b = b[1].split(']')
#         # then get rid of \r\n
#         b = b[0].split('\r\n')
#         #then get rid of j
#         b = [i.split('j')[:-1] for i in b]
#         #then finally separate into complex numbers
#         comp_array= []
#         for two_nums in b:
#             for one_num in two_nums:
#                 #one_num = comp_array[-1]
#                 #find positions of first e
#                 first_e = None
#                 for i in range(len(one_num)):
#                     if one_num[i] == 'e':
#                         first_e = i
#                         break
#                 print(first_e)
#                 real_part = float(one_num[:first_e+4])
#                 imag_part = float(one_num[first_e+4:])
#                 new_num = complex(real_part, imag_part)
#                 comp_array.append(new_num)
#         comp_array
#         new_param_array.append(comp_array)
#     return new_param_array

# %%
#mod_param_df['betas'][1]

# %%
#convert_comp_arr_str_to_orig(mod_param_df['betas'])

# %%
# import ast
#ast.literal_eval(param_df['betas_r'][k])

# %%
#k = 1
#gammas = np.asarray([complex(float(param_df['betas_r'][k][l]),float(param_df['betas_i'][k][l])) for l in range(len(param_df['betas_i'][k]))] )

# %%
#ast.literal_eval("[1e+10,1e-2]")

# %%
times = [50 + 50*i for i in range(10)]

# %%
#param_df = param_df.drop(0)

# %%
from IPython.display import clear_output
import ast

N_times = len(param_df['exact fidelity'])     # No. of optimized sets of parameters


from IPython.display import clear_output
    
for k in range(1,21): 
    print(k)
    #First import parameters
    betas_r = ast.literal_eval(param_df['betas_r'][k])
    betas_i = ast.literal_eval(param_df['betas_i'][k])
    gammas_r = ast.literal_eval(param_df['gammas_r'][k])
    gammas_i = ast.literal_eval(param_df['gammas_i'][k])
    
    betas = np.asarray([complex(betas_r[l], betas_i[l]) for l in range(len(betas_r))] )
    gammas = np.asarray([complex(gammas_r[l], gammas_i[l]) for l in range(len(gammas_r))] )
    #print(betas)
    
    phis = np.asarray(ast.literal_eval(param_df['phis'][k]))
    thetas = np.asarray(ast.literal_eval(param_df['thetas'][k]))
    #print(phis)
    bo_fid = float(param_df['bo_fidelity'][k])
    ex_fid = float(param_df['exact fidelity'][k])
    
    #Then get pulses
    alpha1, alpha1_star, alpha2, alpha2_star, qubit_dac_pulse_GHz, storage1_params, storage2_params = get_pulses(betas, gammas, phis, thetas)
    null_sim_params = {'bare_qubit_mode_coupling':0,'Stark Shift': 0, 'Mode Coupling': 0, 'transmon_relax': 0,'transmon_dephasing': 0 }  # 0 means false, 1 means true or activates
    base_parameters = {'ancilla_T1_mu_s': 50}
    fid_times = []
    for t in times: 
        print('Now adding Transmon Relaxation with ancilla time : ' + str(t))
        sim_params = null_sim_params.copy()
        sim_params['transmon_relax'] = 1
        parameters = base_parameters.copy()
        parameters['ancilla_T1_mu_s'] = t
        tr_fid = get_qutip_sim(alpha1, alpha1_star, alpha2, alpha2_star,
                  qubit_dac_pulse_GHz, storage1_params, storage2_params, 
                                  sim_params,parameters, initial, target)
        print(tr_fid)
        fid_times.append(tr_fid)
    #tr_fids.append(tr_fid)
    
    
    
    #Saving data
    new_row = [[ex_fid, bo_fid, betas, gammas, phis, thetas, fid_times]]
    df_new = pd.DataFrame(new_row, columns=columns)
    df = df.append(df_new, ignore_index = True)
    df.to_csv(fname, index=False)
    
    #clear_output(wait = True)
    print(new_row)
# Out:
# 1
# ---------------------------------------------------
# final displacement is 0.0029942383665772557
# ---------------------------------------------------
# final displacement is 0.5474728800709577
# ---------------------------------------------------
# final displacement is 0.03287335507954956
# ---------------------------------------------------
# final displacement is 0.7369224901840298
# ---------------------------------------------------
# final displacement is 0.06338559245086897
# ---------------------------------------------------
# final displacement is 0.7961936804161966
# ---------------------------------------------------
# final displacement is 1.3308217657353123
# ---------------------------------------------------
# final displacement is 1.310736068951403
# ---------------------------------------------------
# final displacement is 0.9508943760648783
# ---------------------------------------------------
# final displacement is 0.08813503744030267
# ---------------------------------------------------
# final displacement is 1.2561582916635106
# ---------------------------------------------------
# final displacement is 0.38088530723775127
# ---------------------------------------------------
# final displacement is 1.601073936623368
# ---------------------------------------------------
# final displacement is 0.445538628677169
# ---------------------------------------------------
# final displacement is 0.06265820112929185
# ---------------------------------------------------
# final displacement is 0.001068345495296953
# ---------------------------------------------------
# final displacement is 0.4118328319351563
# ---------------------------------------------------
# final displacement is 0.05948406067502819
# ---------------------------------------------------
# final displacement is 0.020736861505215292
# ---------------------------------------------------
# final displacement is 0.06995130207773871
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9267562768394095
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9462844598137663
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.953778089077799
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9572599620094554
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9593505253578807
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9608885033891552
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9618090850133421
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9618835126981319
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9623637149264597
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9634134572066965
# [[0.9955861762929824, 0.9955984, array([-0.00262321-0.00144306j,  0.02715145-0.01854762j,
#        -0.03374483-0.05365012j, -0.63929206+1.1658154j ,
#         0.94250906-0.12600312j, -1.1920416 -0.3972325j ,
#         1.1331254 +1.1311342j ,  0.0538323 -0.0320541j ,
#        -0.3130946 +0.26754075j, -0.00926707+0.01855696j]), array([-0.22359522-4.9973166e-01j, -0.7231863 +1.4162038e-01j,
#         0.68294007+4.1028225e-01j,  0.5221587 -1.2022393e+00j,
#        -0.07673156+4.3360215e-02j,  0.23598076+2.9891050e-01j,
#        -0.24681963-3.7092417e-01j,  0.00099978-3.7624376e-04j,
#         0.05818657-1.2331819e-02j,  0.06029191-3.5469774e-02j]), array([ 0.       ,  1.3961155,  1.2453349,  1.0953438, -2.1847992,
#        -2.28222  , -2.1398375,  0.5079949, -1.3179011,  1.5924122]), array([-1.5561874 ,  2.275472  ,  1.7466791 ,  2.0304034 , -1.5133946 ,
#         0.648654  , -0.19145155,  1.5995128 ,  2.663192  ,  1.4905384 ]), [0.9267562768394095, 0.9462844598137663, 0.953778089077799, 0.9572599620094554, 0.9593505253578807, 0.9608885033891552, 0.9618090850133421, 0.9618835126981319, 0.9623637149264597, 0.9634134572066965]]]
# 2
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.0006482462319518837
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.5013309876991409
# ---------------------------------------------------
# final displacement is 0.6909992385589351
# ---------------------------------------------------
# final displacement is 1.7857450791707619
# ---------------------------------------------------
# final displacement is 1.7989520876095075
# ---------------------------------------------------
# final displacement is 1.6570907208828967
# ---------------------------------------------------
# final displacement is 1.4016415396635906
# ---------------------------------------------------
# final displacement is 1.75704883618276
# ---------------------------------------------------
# final displacement is 0.005772676046901154
# ---------------------------------------------------
# final displacement is 0.7663651105980359
# ---------------------------------------------------
# final displacement is 1.322676004234364
# ---------------------------------------------------
# final displacement is 1.290159444534015
# ---------------------------------------------------
# final displacement is 0.7673816595342213
# ---------------------------------------------------
# final displacement is 0.005719882992326785
# ---------------------------------------------------
# final displacement is 0.7169708698984257
# ---------------------------------------------------
# final displacement is 0.005792304557719158
# ---------------------------------------------------
# final displacement is 0.4897270435796745
# ---------------------------------------------------
# final displacement is 0.002284579582486626
# ---------------------------------------------------
# final displacement is 0.000101259548253744
# ---------------------------------------------------
# final displacement is 0.0019355477780488243
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9289614632494338
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9534116201730521
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.96108742109826
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9652636222162979
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9680991866255065
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9692171434332351
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9694457841283055
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9712017654686547
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9716594393343652
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9734706857569317
# [[0.9964602292444996, 0.99646986, array([-6.4737914e-04-3.2210814e-05j, -5.2747920e-01+4.4636940e-01j,
#        -1.4209414e-01+1.7933315e+00j,  3.8317960e-01+1.3482479e+00j,
#         2.1109937e-03-5.3722140e-03j, -4.2519484e-02-1.3219924e+00j,
#         7.6360520e-01+7.6037556e-02j,  4.9998814e-01-5.1386680e-01j,
#         2.9850295e-01+3.8823777e-01j,  6.1793675e-05+8.0205624e-05j]), array([ 5.0107450e-01+1.6034484e-02j, -1.5052351e+00-9.6080840e-01j,
#         8.4542390e-02-1.6549327e+00j,  1.7569891e+00-1.4488451e-02j,
#         6.3467090e-01-4.2954433e-01j,  1.0823115e+00+7.0222020e-01j,
#        -4.2404365e-03-3.8378474e-03j, -1.3017458e-03+5.6435266e-03j,
#         1.5406075e-03-1.6866433e-03j, -1.8481484e-03+5.7439270e-04j]), array([ 0.        , -1.5745307 , -0.7655482 ,  1.8811753 ,  0.5796933 ,
#        -2.565726  ,  0.5812142 ,  0.5824888 , -2.5467646 , -0.98429704]), array([ 1.5732338, -1.2030032, -3.1294155,  3.1376164, -2.154267 ,
#        -1.2538978,  2.1066706, -1.2576647, -1.9706455, -1.5689137]), [0.9289614632494338, 0.9534116201730521, 0.96108742109826, 0.9652636222162979, 0.9680991866255065, 0.9692171434332351, 0.9694457841283055, 0.9712017654686547, 0.9716594393343652, 0.9734706857569317]]]
# 3
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.0011486762226145671
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 2.669196853887494
# ---------------------------------------------------
# final displacement is 0.0012874628927931897
# ---------------------------------------------------
# final displacement is 0.4325160463205304
# ---------------------------------------------------
# final displacement is 0.027905652923973887
# ---------------------------------------------------
# final displacement is 0.8041940454895575
# ---------------------------------------------------
# final displacement is 0.05290454269102534
# ---------------------------------------------------
# final displacement is 0.8870932565706606
# ---------------------------------------------------
# final displacement is 0.9389371980782063
# ---------------------------------------------------
# final displacement is 2.9856406250838927
# ---------------------------------------------------
# final displacement is 0.9040293914653624
# ---------------------------------------------------
# final displacement is 2.4456291730690802
# ---------------------------------------------------
# final displacement is 0.7684583901124183
# ---------------------------------------------------
# final displacement is 0.055643471068426514
# ---------------------------------------------------
# final displacement is 0.7239818842022377
# ---------------------------------------------------
# final displacement is 0.07726659248052684
# ---------------------------------------------------
# final displacement is 0.48911154137378454
# ---------------------------------------------------
# final displacement is 0.041680833716920204
# ---------------------------------------------------
# final displacement is 0.005368452861404302
# ---------------------------------------------------
# final displacement is 2.664936518745593
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9240037826692744
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9489300381974358
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9577071668420083
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9617744666569479
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9640528303491056
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9663973418820012
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9675681234040227
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9682096384962268
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9691488166250617
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9698206725293127
# [[0.9949359256387298, 0.9956294, array([ 1.0140339e-03+5.3937244e-04j, -4.4833508e-04-1.2067384e-03j,
#         2.1753615e-02+1.7490216e-02j,  5.1265866e-02-1.3047030e-02j,
#         7.5819534e-01+5.5384374e-01j,  5.2275530e-01-7.3756087e-01j,
#        -7.6502275e-01+7.2584360e-02j,  4.0526150e-01-5.9992740e-01j,
#        -3.4799978e-01-3.4369500e-01j,  5.3376245e-04+5.3413007e-03j]), array([ 2.636092  +0.4190833j ,  0.01244382-0.432337j  ,
#        -0.7358306 +0.32447094j,  0.40474427+0.7893773j ,
#        -2.984165  -0.10909101j, -2.2621918 -0.9292956j ,
#         0.01552359-0.05342927j,  0.07718471-0.00356209j,
#        -0.01721631-0.03795516j, -2.6350374 -0.39807606j]), array([ 0.       , -0.7320552,  1.9630716, -2.370027 ,  1.9950516,
#         2.5282571, -0.7764368,  2.5251763,  2.5539582, -2.060015 ]), array([-0.0271492,  1.5207536, -1.6562961,  2.018657 , -1.2864621,
#        -3.1387465,  0.9919865,  1.8733327, -1.2194766,  1.5638993]), [0.9240037826692744, 0.9489300381974358, 0.9577071668420083, 0.9617744666569479, 0.9640528303491056, 0.9663973418820012, 0.9675681234040227, 0.9682096384962268, 0.9691488166250617, 0.9698206725293127]]]
# 4
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.00013026593149183385
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.5525112758076404
# ---------------------------------------------------
# final displacement is 0.0021145804001269915
# ---------------------------------------------------
# final displacement is 0.7961936804162041
# ---------------------------------------------------
# final displacement is 0.001713550232527021
# ---------------------------------------------------
# final displacement is 0.8635286629426923
# ---------------------------------------------------
# final displacement is 1.4054530312912976
# ---------------------------------------------------
# final displacement is 1.5596203387998568
# ---------------------------------------------------
# final displacement is 0.816889093929431
# ---------------------------------------------------
# final displacement is 0.0015074176902732652
# ---------------------------------------------------
# final displacement is 3.0354358919542337
# ---------------------------------------------------
# final displacement is 2.6992460533334377
# ---------------------------------------------------
# final displacement is 0.7776919387906759
# ---------------------------------------------------
# final displacement is 2.71204322296975
# ---------------------------------------------------
# final displacement is 2.553971207113093
# ---------------------------------------------------
# final displacement is 0.01397353534172124
# ---------------------------------------------------
# final displacement is 0.5799177205515899
# ---------------------------------------------------
# final displacement is 0.0013193912341624649
# ---------------------------------------------------
# final displacement is 0.010108744604168354
# ---------------------------------------------------
# final displacement is 0.009245452432404008
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9198186245134586
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9475064562368978
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9556066398641072
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9602333431134112
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9630854415297738
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9650181808953029
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.966888836897381
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.966868867777423
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9688362341736934
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9683286118176284
# [[0.995886164396462, 0.9958328, array([ 6.5347767e-06-1.30088590e-04j,  2.0591020e-03+4.80245040e-04j,
#         9.1636250e-04-1.44773410e-03j, -1.4060676e+00-3.70454140e-03j,
#         3.0288080e-02+8.16327400e-01j,  2.7399890e+00-1.30262080e+00j,
#        -5.8475590e-01+5.12703900e-01j,  2.5510190e+00-1.22763954e-01j,
#        -3.9401123e-01+4.25511120e-01j,  2.8729192e-03-9.69082900e-03j]), array([-3.8990060e-01-3.9146677e-01j,  5.7316244e-01-5.5157095e-01j,
#        -7.9313590e-01+3.4149260e-01j,  1.8173245e-01+1.5489961e+00j,
#         9.6478600e-04-1.1580292e-03j, -2.4349418e+00-1.1651034e+00j,
#         2.4416807e+00+1.1758933e+00j,  5.0055960e-03+1.3044684e-02j,
#        -4.2428114e-04+1.2491689e-03j, -5.3429950e-03+7.5440920e-03j]), array([ 0.        , -1.5533143 , -1.5631359 , -1.597816  , -1.626034  ,
#        -1.6353753 , -0.38526773, -0.27387214,  1.0983522 , -0.45735598]), array([ 1.5757606e+00, -1.1407130e+00,  1.5744059e+00,  2.4605734e+00,
#         9.5235944e-01, -1.6148819e+00,  2.2892952e-03, -3.1331623e+00,
#        -2.2819169e+00,  1.5623600e+00]), [0.9198186245134586, 0.9475064562368978, 0.9556066398641072, 0.9602333431134112, 0.9630854415297738, 0.9650181808953029, 0.966888836897381, 0.966868867777423, 0.9688362341736934, 0.9683286118176284]]]
# 5
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 1.582638614275041
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 1.438957698697987
# ---------------------------------------------------
# final displacement is 0.016098561484088284
# ---------------------------------------------------
# final displacement is 0.9764473364338792
# ---------------------------------------------------
# final displacement is 0.01877050422897349
# ---------------------------------------------------
# final displacement is 0.6128005535824406
# ---------------------------------------------------
# final displacement is 0.01634275441640846
# ---------------------------------------------------
# final displacement is 1.3393553017319029
# ---------------------------------------------------
# final displacement is 1.4928751268697171
# ---------------------------------------------------
# final displacement is 1.5590872205463382
# ---------------------------------------------------
# final displacement is 1.5465410741186563
# ---------------------------------------------------
# final displacement is 0.03991859830040269
# ---------------------------------------------------
# final displacement is 0.9326872102596673
# ---------------------------------------------------
# final displacement is 0.032006246000640816
# ---------------------------------------------------
# final displacement is 0.6159028727571588
# ---------------------------------------------------
# final displacement is 0.005734680052450212
# ---------------------------------------------------
# final displacement is 0.6415969536346937
# ---------------------------------------------------
# final displacement is 0.005136870974274558
# ---------------------------------------------------
# final displacement is 1.5796203628585994
# ---------------------------------------------------
# final displacement is 1.434611470450539
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9397597996954877
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9649460000035721
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9735577063696881
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9780104760824505
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9808796934389501
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9824917677082414
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9838478527152001
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9845675338809109
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9852815083440017
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9861534167407816
# [[0.996190699981404, 0.99619323, array([ 6.5717466e-02+1.5812736j , -1.1736141e-02+0.01101697j,
#         5.3034370e-04-0.01876109j,  3.5535956e-03+0.01595002j,
#         1.3877428e+00+0.54737395j,  4.9844050e-01-1.4640172j ,
#         3.1041184e-01-0.87953097j,  5.3378887e-02+0.6135854j ,
#         6.3858170e-01-0.06212941j,  6.5674044e-02+1.5773599j ]), array([ 1.418391  +0.24241747j,  0.33849597-0.9158984j ,
#         0.12522796+0.6000691j , -1.0475554 -0.83456594j,
#         0.7408813 -1.3718046j , -0.02283603+0.03273742j,
#        -0.01590899+0.02778187j, -0.00487241+0.00302316j,
#         0.0047065 +0.00205693j,  1.414071  +0.24189518j]), array([ 0.        ,  0.81113863, -2.1159046 , -1.3001214 ,  0.8784411 ,
#        -0.24235177,  2.0415862 , -1.6172189 , -1.6345814 ,  2.0612438 ]), array([ 3.136113  , -1.5799026 ,  0.99619174,  0.77288556,  1.5324214 ,
#         0.9116552 , -2.8844054 ,  1.202893  ,  1.331187  ,  1.5771587 ]), [0.9397597996954877, 0.9649460000035721, 0.9735577063696881, 0.9780104760824505, 0.9808796934389501, 0.9824917677082414, 0.9838478527152001, 0.9845675338809109, 0.9852815083440017, 0.9861534167407816]]]
# 6
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.002139859681975758
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.49862160506077063
# ---------------------------------------------------
# final displacement is 1.990510762621726
# ---------------------------------------------------
# final displacement is 2.0459821262626177
# ---------------------------------------------------
# final displacement is 1.9863594410063465
# ---------------------------------------------------
# final displacement is 2.467626205366833
# ---------------------------------------------------
# final displacement is 1.8411203150506734
# ---------------------------------------------------
# final displacement is 1.115984054104769
# ---------------------------------------------------
# final displacement is 1.8442460142124106
# ---------------------------------------------------
# final displacement is 1.0947923312959085
# ---------------------------------------------------
# final displacement is 1.2689394413632582
# ---------------------------------------------------
# final displacement is 1.3623377642196421
# ---------------------------------------------------
# final displacement is 0.7712948116718129
# ---------------------------------------------------
# final displacement is 0.0029940595295369276
# ---------------------------------------------------
# final displacement is 0.7123278931044366
# ---------------------------------------------------
# final displacement is 0.005322346518288801
# ---------------------------------------------------
# final displacement is 0.4951661265609894
# ---------------------------------------------------
# final displacement is 0.01183070747837553
# ---------------------------------------------------
# final displacement is 0.024423667048044197
# ---------------------------------------------------
# final displacement is 0.021947471419762422
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.927279695239411
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9540382168756641
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9629089473909281
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9678508218538038
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9700434828342898
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9717454710006552
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9732751897351138
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9741337691014743
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9752328768614305
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9757846230489258
# [[0.9967679168582324, 0.9967786, array([ 1.38473530e-03+1.6311259e-03j,  1.09282150e+00+1.6620002e+00j,
#         1.07876090e+00+1.6679025e+00j,  1.83999530e+00-5.8019146e-02j,
#        -1.84359810e+00+4.8881557e-02j, -5.43458500e-01+1.1467664e+00j,
#        -5.75676740e-01-5.1370690e-01j, -6.68986740e-01+2.4467891e-01j,
#        -1.09228976e-01-4.8296845e-01j,  5.20226660e-04-2.4424430e-02j]), array([ 9.3426320e-02-4.8979080e-01j,  3.3189622e-01+2.0188828e+00j,
#         1.0272089e+00+2.2436624e+00j,  1.0161271e-01+1.1113484e+00j,
#        -7.8794130e-01-7.5886303e-01j, -5.6446093e-01-1.2398984e+00j,
#         1.6962017e-04-2.9889445e-03j, -4.5455880e-03-2.7675282e-03j,
#         1.1813587e-02-6.1334650e-04j,  2.0204792e-02+8.5852500e-03j]), array([ 0.        ,  1.5340307 , -2.4499028 , -0.18119884,  3.1144474 ,
#         2.9104502 , -0.28737712, -0.32501817, -0.3509817 , -1.9244143 ]), array([ 1.5795605 , -1.1847471 ,  3.134495  ,  1.8186929 ,  0.03039694,
#        -2.1947927 ,  1.9533451 , -1.1493877 ,  1.9979374 , -1.593501  ]), [0.927279695239411, 0.9540382168756641, 0.9629089473909281, 0.9678508218538038, 0.9700434828342898, 0.9717454710006552, 0.9732751897351138, 0.9741337691014743, 0.9752328768614305, 0.9757846230489258]]]
# 7
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.024678454639064522
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.4566471969753709
# ---------------------------------------------------
# final displacement is 0.01754195337431884
# ---------------------------------------------------
# final displacement is 0.7490628400096329
# ---------------------------------------------------
# final displacement is 1.2875468269251762
# ---------------------------------------------------
# final displacement is 2.7834799931527114
# ---------------------------------------------------
# final displacement is 0.001519534061301538
# ---------------------------------------------------
# final displacement is 1.5987216178634336
# ---------------------------------------------------
# final displacement is 1.2875450662161094
# ---------------------------------------------------
# final displacement is 2.2080900548291087
# ---------------------------------------------------
# final displacement is 1.3435720213069988
# ---------------------------------------------------
# final displacement is 1.2191998651015838
# ---------------------------------------------------
# final displacement is 0.772308406468874
# ---------------------------------------------------
# final displacement is 0.026373571834500942
# ---------------------------------------------------
# final displacement is 0.7227697717809521
# ---------------------------------------------------
# final displacement is 0.018256745985337643
# ---------------------------------------------------
# final displacement is 0.4937816997837469
# ---------------------------------------------------
# final displacement is 0.02740552560708772
# ---------------------------------------------------
# final displacement is 0.002502802483521756
# ---------------------------------------------------
# final displacement is 0.0010683967544234257
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9389781022086322
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9629217947161115
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9710049444730087
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9746297450156834
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9778483047892953
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9786471342372551
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9797488125647746
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9810755197220571
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9811582691858566
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9825523988624627
# [[0.9964234856282884, 0.996423, array([-0.02452667-2.7897577e-03j, -0.00146851+1.7478578e-02j,
#         0.731406  +1.0596330e+00j, -0.00140653-5.7461400e-04j,
#         0.71992266+1.0674660e+00j,  0.11761218+1.3388621e+00j,
#         0.757472  -1.5065339e-01j, -0.57167447-4.4224930e-01j,
#        -0.24993941+4.2585286e-01j, -0.00173874+1.7998631e-03j]), array([-3.7821588e-01-2.5588945e-01j, -6.1016450e-01+4.3450480e-01j,
#        -2.2035275e+00-1.7006550e+00j,  1.1340028e+00-1.1269199e+00j,
#        -7.5603290e-01-2.0746267e+00j,  1.2182211e+00-3.5383653e-02j,
#        -8.7319780e-03-2.4893310e-02j,  4.2158565e-03-1.7761396e-02j,
#        -1.1340694e-02-2.4956746e-02j,  1.0296772e-03-2.8461058e-04j]), array([ 0.        ,  1.5692036 ,  1.5720084 , -1.3431681 ,  2.1121037 ,
#        -0.48868012,  2.649543  , -0.48693705, -0.489254  , -2.05209   ]), array([-1.5716397 ,  1.3233197 , -2.0805616 ,  0.00391269,  3.1310837 ,
#        -1.2531378 ,  2.1392825 , -1.8507799 , -1.9716334 , -1.5755298 ]), [0.9389781022086322, 0.9629217947161115, 0.9710049444730087, 0.9746297450156834, 0.9778483047892953, 0.9786471342372551, 0.9797488125647746, 0.9810755197220571, 0.9811582691858566, 0.9825523988624627]]]
# 8
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.0015057063701690385
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.5754903108241926
# ---------------------------------------------------
# final displacement is 0.00144953596567157
# ---------------------------------------------------
# final displacement is 0.8331794388556577
# ---------------------------------------------------
# final displacement is 0.0066119216365653505
# ---------------------------------------------------
# final displacement is 0.9224440716911366
# ---------------------------------------------------
# final displacement is 1.6251847858030792
# ---------------------------------------------------
# final displacement is 1.6542721322441287
# ---------------------------------------------------
# final displacement is 0.14592616012352916
# ---------------------------------------------------
# final displacement is 1.560768767952301
# ---------------------------------------------------
# final displacement is 1.134029094499849
# ---------------------------------------------------
# final displacement is 1.5594485268163725
# ---------------------------------------------------
# final displacement is 0.6546226868270341
# ---------------------------------------------------
# final displacement is 0.003980870040165455
# ---------------------------------------------------
# final displacement is 1.7699666703015395
# ---------------------------------------------------
# final displacement is 0.06485961505951898
# ---------------------------------------------------
# final displacement is 1.3655076845189407
# ---------------------------------------------------
# final displacement is 0.07434674361070158
# ---------------------------------------------------
# final displacement is 0.012608024495899471
# ---------------------------------------------------
# final displacement is 0.00878407980638212
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9425389499251368
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9675323008760628
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9763808268369345
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.98018187094041
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9831602637232864
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9845394613099164
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.985962500649184
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9859403415092863
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9882274805893198
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9874027900972814
# [[0.996414670008211, 0.9964247, array([ 1.4479039e-03-4.1262887e-04j,  3.3884450e-04-1.4092230e-03j,
#         4.7782534e-03-4.5691210e-03j,  2.3481761e-01+1.6081313e+00j,
#         1.4352043e-01-2.6390927e-02j, -1.1288726e+00+1.0802148e-01j,
#        -5.0121504e-01-4.2108710e-01j,  9.3748313e-01-1.5013019e+00j,
#        -1.2862180e+00+4.5853516e-01j, -9.5044120e-04-1.2570857e-02j]), array([-0.4419903 +0.3685562j , -0.5735252 -0.605279j  ,
#         0.7638508 +0.5171412j ,  0.3190096 -1.6222814j ,
#        -0.32655182+1.5262251j , -0.32731694+1.5247109j ,
#        -0.00324738-0.00230188j,  0.05786256+0.02929124j,
#        -0.06552458-0.03512843j,  0.0078889 +0.00386129j]), array([ 0.        ,  1.5909874 ,  1.6046488 ,  1.6256077 ,  1.6075547 ,
#        -0.7116964 , -3.0724719 ,  0.05487585,  0.03043413, -1.5249993 ]), array([-1.5605228 , -2.0086124 , -1.5044947 ,  0.60257816,  1.5031025 ,
#        -3.1319005 ,  2.2089841 , -2.3677917 ,  0.10950708, -1.5822018 ]), [0.9425389499251368, 0.9675323008760628, 0.9763808268369345, 0.98018187094041, 0.9831602637232864, 0.9845394613099164, 0.985962500649184, 0.9859403415092863, 0.9882274805893198, 0.9874027900972814]]]
# 9
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.04367637526433891
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.49727069610160546
# ---------------------------------------------------
# final displacement is 0.47076519462131455
# ---------------------------------------------------
# final displacement is 2.5419748771158504
# ---------------------------------------------------
# final displacement is 0.27540014438541116
# ---------------------------------------------------
# final displacement is 0.8882614474625857
# ---------------------------------------------------
# final displacement is 0.739276818857205
# ---------------------------------------------------
# final displacement is 2.236364658102529
# ---------------------------------------------------
# final displacement is 0.03066777369705787
# ---------------------------------------------------
# final displacement is 0.7731416115038187
# ---------------------------------------------------
# final displacement is 1.2561582916635083
# ---------------------------------------------------
# final displacement is 1.3187381181844653
# ---------------------------------------------------
# final displacement is 0.762980588344177
# ---------------------------------------------------
# final displacement is 0.03583599240078774
# ---------------------------------------------------
# final displacement is 0.7095974674802479
# ---------------------------------------------------
# final displacement is 0.03712701103100058
# ---------------------------------------------------
# final displacement is 0.49043555280974654
# ---------------------------------------------------
# final displacement is 0.014337690474555772
# ---------------------------------------------------
# final displacement is 0.021170860802409118
# ---------------------------------------------------
# final displacement is 0.012761653211965675
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9127376311405143
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9348760290273798
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9426026073843781
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9461981914755481
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9489860733241975
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.949903276627072
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9520644979323686
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9522073678052985
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9524257837763179
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9520280269711416
# [[0.99653909002923, 0.99652594, array([ 0.01475754-0.04110372j,  0.4100612 -0.23123512j,
#         0.05633239-0.26953924j,  0.5295176 -0.51588887j,
#        -0.02387109-0.01926574j, -1.2180521 +0.30782455j,
#         0.02476095-0.7625787j ,  0.6108715 +0.36106035j,
#        -0.32723367+0.36530146j,  0.01515078-0.01479495j]), array([-0.43818113+0.2351073j , -2.1519425 +1.3530631j ,
#         0.21571338-0.86167055j, -2.2296283 -0.17344892j,
#        -0.7369317 -0.23383674j, -0.5077324 +1.2184631j ,
#         0.02889323-0.02119389j,  0.03259353+0.01777195j,
#        -0.00328384+0.01395506j,  0.00452219-0.01193215j]), array([ 0.        , -1.567324  ,  1.4665563 ,  1.599829  , -1.505326  ,
#         1.6370285 ,  1.6660264 , -1.4549311 , -1.3677839 ,  0.24269843]), array([-1.5563223 , -1.123174  , -0.00695944, -3.1257498 , -1.3004458 ,
#         1.0302589 , -1.9931899 ,  2.0072997 ,  1.9526708 ,  1.5211318 ]), [0.9127376311405143, 0.9348760290273798, 0.9426026073843781, 0.9461981914755481, 0.9489860733241975, 0.949903276627072, 0.9520644979323686, 0.9522073678052985, 0.9524257837763179, 0.9520280269711416]]]
# 10
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 1.1795739008497772
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 1.0932691828361252
# ---------------------------------------------------
# final displacement is 0.06515137683447214
# ---------------------------------------------------
# final displacement is 0.4123961541643898
# ---------------------------------------------------
# final displacement is 0.12295161284537495
# ---------------------------------------------------
# final displacement is 0.6852100657137316
# ---------------------------------------------------
# final displacement is 0.7464451585665793
# ---------------------------------------------------
# final displacement is 0.602504742959071
# ---------------------------------------------------
# final displacement is 0.7712948116718046
# ---------------------------------------------------
# final displacement is 0.4846526154113466
# ---------------------------------------------------
# final displacement is 0.5267686156779474
# ---------------------------------------------------
# final displacement is 0.6358444328144705
# ---------------------------------------------------
# final displacement is 0.7199611701940472
# ---------------------------------------------------
# final displacement is 0.7006547841554646
# ---------------------------------------------------
# final displacement is 0.6994693463649501
# ---------------------------------------------------
# final displacement is 0.28221591387677025
# ---------------------------------------------------
# final displacement is 0.37620896408186916
# ---------------------------------------------------
# final displacement is 0.24901033772172276
# ---------------------------------------------------
# final displacement is 1.1917079514832871
# ---------------------------------------------------
# final displacement is 1.1175016736502836
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9121931394141849
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9319784384001933
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9386803349836617
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9419307438204629
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9435679747228952
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9450684294078392
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.946292380152916
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.946752218073761
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9477535735208833
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9479356340113193
# [[0.9954101832945028, 0.99541944, array([-0.13434817-1.1718981j ,  0.06487343-0.00595118j,
#         0.02883739+0.11952243j,  0.09745285+0.74012125j,
#         0.69198245-0.3392997j ,  0.26970804+0.45248508j,
#         0.70575327-0.14232501j, -0.00754056+0.6994287j ,
#        -0.37548116-0.02255724j,  0.13083169+1.1845045j ]), array([ 0.3952284 +1.0193292j ,  0.39807162+0.10774773j,
#        -0.2416246 +0.6411945j , -0.49088234-0.3488023j ,
#        -0.359523  +0.3250098j , -0.43842268-0.46122736j,
#        -0.67291373+0.19520307j, -0.02009052-0.28146166j,
#         0.18362534-0.16814019j, -0.37311766-1.0533723j ]), array([ 0.        , -0.25606656,  1.6486723 ,  1.1250317 ,  0.79213166,
#         2.6117342 , -1.0943444 ,  0.38715315,  0.5506704 ,  2.8035772 ]), array([-0.02907538,  1.589442  ,  1.7153823 ,  1.757087  , -1.2909902 ,
#        -1.6710417 , -1.5531545 , -1.7267174 , -1.5511318 , -1.5819533 ]), [0.9121931394141849, 0.9319784384001933, 0.9386803349836617, 0.9419307438204629, 0.9435679747228952, 0.9450684294078392, 0.946292380152916, 0.946752218073761, 0.9477535735208833, 0.9479356340113193]]]
# 11
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.6717922964827616
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 1.0994164974281524
# ---------------------------------------------------
# final displacement is 0.374062211943473
# ---------------------------------------------------
# final displacement is 3.582727692566999
# ---------------------------------------------------
# final displacement is 0.385821645094396
# ---------------------------------------------------
# final displacement is 4.055460706736785
# ---------------------------------------------------
# final displacement is 0.0016259592368980849
# ---------------------------------------------------
# final displacement is 0.733666633269132
# ---------------------------------------------------
# final displacement is 0.008329196913893295
# ---------------------------------------------------
# final displacement is 0.7594089702562508
# ---------------------------------------------------
# final displacement is 1.2984967627582584
# ---------------------------------------------------
# final displacement is 1.278355490391072
# ---------------------------------------------------
# final displacement is 0.7685996360605476
# ---------------------------------------------------
# final displacement is 0.011176355041003108
# ---------------------------------------------------
# final displacement is 0.7018181808723675
# ---------------------------------------------------
# final displacement is 0.013208069831559862
# ---------------------------------------------------
# final displacement is 0.49229891578403207
# ---------------------------------------------------
# final displacement is 0.010224474861343135
# ---------------------------------------------------
# final displacement is 0.6667845681199236
# ---------------------------------------------------
# final displacement is 1.106889722769495
# ...
# final displacement is 1.2961643188889294
# ---------------------------------------------------
# final displacement is 1.0213136877492734
# ---------------------------------------------------
# final displacement is 1.0450153875695654
# ---------------------------------------------------
# final displacement is 0.556876829684018
# ---------------------------------------------------
# final displacement is 0.7272346058028275
# ---------------------------------------------------
# final displacement is 0.6750441153793328
# ---------------------------------------------------
# final displacement is 0.6120951249419021
# ---------------------------------------------------
# final displacement is 0.5459825064872209
# ---------------------------------------------------
# final displacement is 0.02968357408458203
# ---------------------------------------------------
# final displacement is 0.36635728817865854
# ---------------------------------------------------
# final displacement is 0.022861182920631138
# ---------------------------------------------------
# final displacement is 0.3062750463379209
# ---------------------------------------------------
# final displacement is 0.01897694231801504
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.92242595860439
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9424419749062357
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9488338759311807
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9530349459444464
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.954181198571724
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9557856022717278
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9571151498324447
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9579381678250074
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9582709239284699
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9589671241982425
# [[0.9955136565017592, 0.9955268, array([-0.02359953+0.17487738j,  0.12864238+0.06771363j,
#        -0.1544991 -0.7662739j ,  1.1223801 +0.85595816j,
#        -0.42071894-0.9306327j , -0.15147737-0.5358791j ,
#        -0.6548285 +0.163964j  , -0.04524637+0.54410446j,
#        -0.36587209+0.01786055j,  0.24487107+0.18389456j]), array([-0.41124973+0.14435014j,  0.16735496+0.7470328j ,
#         0.7593758 -0.1817234j , -0.41310588+1.2285705j ,
#         0.5796703 -0.8701371j ,  0.6680642 -0.28733325j,
#        -0.16842061-0.5884683j ,  0.01775144+0.02380033j,
#        -0.02142217+0.00799962j,  0.0133991 +0.01343558j]), array([ 0.       , -1.5606408,  1.6027138,  1.6216185, -1.5150527,
#         1.6330898,  1.6402161, -1.0444472,  2.911342 , -1.3905357]), array([ 1.5928729 ,  1.4919174 , -1.476476  ,  1.473964  ,  0.18991017,
#        -1.7089945 , -1.4191298 ,  1.4341123 ,  2.2728279 ,  0.82562137]), [0.92242595860439, 0.9424419749062357, 0.9488338759311807, 0.9530349459444464, 0.954181198571724, 0.9557856022717278, 0.9571151498324447, 0.9579381678250074, 0.9582709239284699, 0.9589671241982425]]]
# 14
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.0044349709312486475
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.679566627613175
# ---------------------------------------------------
# final displacement is 0.02082421497084107
# ---------------------------------------------------
# final displacement is 0.8263000572561369
# ---------------------------------------------------
# final displacement is 0.03609057816566218
# ---------------------------------------------------
# final displacement is 0.8606374134603092
# ---------------------------------------------------
# final displacement is 0.7975321033178083
# ---------------------------------------------------
# final displacement is 1.0699039599433477
# ---------------------------------------------------
# final displacement is 1.6228786453471364
# ---------------------------------------------------
# final displacement is 1.9030645057738607
# ---------------------------------------------------
# final displacement is 0.7585350302128806
# ---------------------------------------------------
# final displacement is 0.08413654450519528
# ---------------------------------------------------
# final displacement is 0.7235773263206848
# ---------------------------------------------------
# final displacement is 0.1538731818444902
# ---------------------------------------------------
# final displacement is 0.40966921607915463
# ---------------------------------------------------
# final displacement is 0.09437464964877483
# ---------------------------------------------------
# final displacement is 0.7842766414932771
# ---------------------------------------------------
# final displacement is 0.20626773074003055
# ---------------------------------------------------
# final displacement is 0.5702822499395405
# ---------------------------------------------------
# final displacement is 0.21561308242662106
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.937543100270911
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9595631449444888
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9657049528059506
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9698650122362764
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9718444077624577
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9739720560458239
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9753861048845507
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9752265952562432
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9758694884876994
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.9766114568807586
# [[0.995435326409798, 0.9954473, array([ 3.8583355e-04+0.0044177j ,  1.0304817e-02-0.018102j  ,
#         2.8765421e-02+0.02179125j, -3.8273910e-01+0.69969153j,
#        -1.5976481e+00+0.28505376j, -4.5824784e-01+0.6039621j ,
#         2.8416760e-01+0.6654419j , -3.8971227e-01+0.12630603j,
#         7.7225477e-01-0.13679335j, -5.6357557e-01+0.08393974j]), array([ 0.6786639 -0.03501588j,  0.4678808 +0.6810722j ,
#        -0.71788025-0.47470486j,  0.86706346+0.62539977j,
#         0.03902583+1.9022025j ,  0.05055785-0.0672526j ,
#        -0.14602575+0.04844623j, -0.08116428-0.04815597j,
#         0.1479084 +0.14372885j, -0.16134399-0.14298445j]), array([ 0.        , -1.3452626 ,  1.9926999 , -1.0770557 ,  0.30014873,
#        -1.5684384 ,  1.5949738 ,  2.2437384 , -2.229773  , -2.5945005 ]), array([-1.5263152 ,  2.5195239 , -1.5366302 ,  2.076894  , -3.1201885 ,
#         1.1431496 , -1.1174262 ,  2.0144403 ,  1.2757075 , -0.31594205]), [0.937543100270911, 0.9595631449444888, 0.9657049528059506, 0.9698650122362764, 0.9718444077624577, 0.9739720560458239, 0.9753861048845507, 0.9752265952562432, 0.9758694884876994, 0.9766114568807586]]]
# 15
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 0.005723200799722445
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 0.5609273830611539
# ---------------------------------------------------
# final displacement is 0.012665906334443873
# ---------------------------------------------------
# final displacement is 0.8808170990146327
# ---------------------------------------------------
# final displacement is 0.012662365242158621
# ---------------------------------------------------
# final displacement is 1.5642244070050524
# ---------------------------------------------------
# final displacement is 0.003398592935950148
# ---------------------------------------------------
# final displacement is 0.7689736086705999
# ---------------------------------------------------
# final displacement is 1.5675275529206698
# ---------------------------------------------------
# final displacement is 1.321255567124626
# ---------------------------------------------------
# final displacement is 1.2529405042301025
# ---------------------------------------------------
# final displacement is 0.0022853657506728573
# ---------------------------------------------------
# final displacement is 0.6453011325288648
# ---------------------------------------------------
# final displacement is 0.00032621491370122424
# ---------------------------------------------------
# final displacement is 1.1133322701453534
# ---------------------------------------------------
# final displacement is 0.0016474671214288974
# ---------------------------------------------------
# final displacement is 1.2528448408137498
# ---------------------------------------------------
# final displacement is 1.3308217657353234
# ---------------------------------------------------
# final displacement is 1.0699039599433506
# ---------------------------------------------------
# final displacement is 1.3092216506608014
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9291962376816898
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9529651075617576
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9619808261593725
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9657798308795174
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.9677869567117441
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.969618714265644
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9706273081842517
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9721365433628771
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9724265770987787
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution
# finished evolution
# 0.972767623334906
# [[0.995630297534452, 0.99563974, array([-0.00539527+0.00190772j, -0.01123076+0.0058534j ,
#        -0.01082425+0.00656798j,  0.00250686-0.00229428j,
#         0.92059594-1.2668998j , -0.89867556-0.8730648j ,
#        -0.00161962-0.6452991j , -0.49631068+0.9965864j ,
#         0.7394258 -1.0113702j ,  0.6136315 -0.87749654j]), array([-3.8381312e-02-5.5994600e-01j, -6.9082750e-01-5.4643950e-01j,
#        -1.4893430e+00-4.7817928e-01j, -6.0254264e-01-4.7776854e-01j,
#        -7.8353080e-01+1.0638589e+00j,  1.8624745e-03+1.3240158e-03j,
#         3.2588054e-04-1.4010463e-05j,  1.6088459e-03+3.5384748e-04j,
#         7.1845950e-01+1.1195048e+00j,  7.6935790e-01+1.0593157e+00j]), array([ 0.        ,  1.5325372 ,  1.73052   ,  1.9503105 , -1.095568  ,
#        -1.0194759 , -0.55930257, -0.3712561 , -2.0188859 , -0.02723622]), array([-1.6246727, -1.2640513, -3.0303385, -1.4045855, -2.3392124,
#        -1.5336277, -2.1440282,  0.7982633,  1.3786862, -3.1317265]), [0.9291962376816898, 0.9529651075617576, 0.9619808261593725, 0.9657798308795174, 0.9677869567117441, 0.969618714265644, 0.9706273081842517, 0.9721365433628771, 0.9724265770987787, 0.972767623334906]]]
# 16
# /tmp/ipykernel_27709/328290030.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_new, ignore_index = True)
# ---------------------------------------------------
# final displacement is 1.6145894339089418e-05
# /home/eag190/miniconda3/envs/simulations/lib/python3.9/site-packages/scipy/signal/_peak_finding.py:261: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)
# ---------------------------------------------------
# final displacement is 1.2191998651015825
# ---------------------------------------------------
# final displacement is 0.0006660897935261572
# ---------------------------------------------------
# final displacement is 0.7023692662950128
# ---------------------------------------------------
# final displacement is 0.0008066755294180043
# ---------------------------------------------------
# final displacement is 1.1839616185297828
# ---------------------------------------------------
# final displacement is 0.3150399033920768
# ---------------------------------------------------
# final displacement is 2.6244795523172013
# ---------------------------------------------------
# final displacement is 1.724259391925272
# ---------------------------------------------------
# final displacement is 2.6742583179012946
# ---------------------------------------------------
# final displacement is 1.47553497475425
# ---------------------------------------------------
# final displacement is 0.02248520644709639
# ---------------------------------------------------
# final displacement is 1.0184948406409924
# ---------------------------------------------------
# final displacement is 0.017745367917216728
# ---------------------------------------------------
# final displacement is 0.9636214670588719
# ---------------------------------------------------
# final displacement is 0.00022430216562829616
# ---------------------------------------------------
# final displacement is 0.6025047429590841
# ---------------------------------------------------
# final displacement is 0.005801493595680902
# ---------------------------------------------------
# final displacement is 0.03984087880881083
# ---------------------------------------------------
# final displacement is 0.00410537491337998
# Now adding Transmon Relaxation with ancilla time : 50
# starting evolution
# finished evolution
# 0.9244598985235809
# Now adding Transmon Relaxation with ancilla time : 100
# starting evolution
# finished evolution
# 0.9494512827086625
# Now adding Transmon Relaxation with ancilla time : 150
# starting evolution
# finished evolution
# 0.9586661948394676
# Now adding Transmon Relaxation with ancilla time : 200
# starting evolution
# finished evolution
# 0.9617853580870827
# Now adding Transmon Relaxation with ancilla time : 250
# starting evolution
# finished evolution
# 0.964338524457657
# Now adding Transmon Relaxation with ancilla time : 300
# starting evolution
# finished evolution
# 0.9661780677919402
# Now adding Transmon Relaxation with ancilla time : 350
# starting evolution
# finished evolution
# 0.9677228395123654
# Now adding Transmon Relaxation with ancilla time : 400
# starting evolution
# finished evolution
# 0.9680825745914791
# Now adding Transmon Relaxation with ancilla time : 450
# starting evolution
# finished evolution
# 0.9694555619030935
# Now adding Transmon Relaxation with ancilla time : 500
# starting evolution

# %%
df

# %%
param_df

# %%
# BO_fids = [0.9,0.8]
# mm_fids = BO_fids
# ss_fids = BO_fids
# ecd_fids = BO_fids

# %%
lf = pd.read_csv(fname)
result_df = lf.drop(0)

# %%
result_df

# %%
# results = result_df['transmon_relax']
# list(results)

# %%
# import matplotlib.pyplot as plt
results = result_df['transmon_relax']

# means = 1- np.mean(fids) for fids in results]
# errs = [np.std(fids) for fids in results ]

# # Build the plot
# fig, ax = plt.subplots(figsize = (8,6))
# ax.bar(x_pos, means, yerr=errs, align='center', alpha=0.5, ecolor='black', capsize=10)
# ax.set_ylabel('$1-\mathcal{F}$')
# ax.set_xticks(x_pos)
# ax.set_xticklabels(conditions, fontsize = 15)
# ax.set_title('Decoherence Free Error Budget')
# ax.yaxis.grid(True)

# # Save the figure and show
# plt.tight_layout()
# #plt.savefig('Decoherence Free Error Budget.png')
# plt.show()

# %%
# import matplotlib.pyplot as plt
# plt.rcParams['font.size'] = 12
# figure = plt.figure(figsize= (8, 6))
# # plt.plot(layers, qutip_diffs, marker = 'o', linestyle = '--',label = 'Qutip')
# # plt.plot(layers, BO_diffs, marker = 'o',label = 'Batch Optimizer (Using BCH approx)')
# plt.errorbar(layers, qutip_diffs, yerr = qutip_errs,capsize=10,  fmt ='o', label = 'Qutip')
# plt.errorbar(layers, BO_diffs, yerr = BO_errs,capsize=10, fmt ='o', label = 'Batch Optimizer (Using BCH approx)')

# #plt.plot(layers, rep_fids, marker = 'o', linestyle = '--',label = 'True Fidelity' )
# plt.xlabel('Layers')
# plt.ylabel(' Error from Exact Fidelity')
# plt.legend()

# %%
# def diff_arrays(a,b):
#     '''
#     Input : two arrays ; a = [a1, a2, ..., aN], b = [b1, b2, ..., bN]
#     Output : c = [a1 -b1, a2 - b2, .....]
#     '''
#     c = [a[i]- b[i] for i in range(len(a))]
#     return c

# %%
#null_sim_params = {'bare_qubit_mode_coupling':0,'Stark Shift': 0, 'Mode Coupling': 0, 'transmon_relax': 0,'transmon_dephasing': 0 }  # 0 means false, 1 means true or activates

# %%
#d = null_sim_params.copy()

# %%
#d['Stark Shift'] = 1

# %%
#d

# %%
#null_sim_params
