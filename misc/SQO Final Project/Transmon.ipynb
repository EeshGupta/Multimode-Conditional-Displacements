# %%
# %matplotlib inline
import numpy as np
import scqubits as scq

# %%
transmon = scq.Transmon(
    EJ=30,
    EC=0.150,
    ng=0.3,
    ncut=31
)

# %%
transmon.eigenvals(evals_count=12)
# Out:
# array([-27.03798737, -21.19200852, -15.50557606,  -9.9861585 ,
#         -4.64251559,   0.51488438,   5.47323164,  10.21634111,
#         14.72302627,  18.96181938,  22.89732659,  26.35884166])

# %%
transmon.plot_wavefunction(esys=None, which=range(14), mode='real')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %%
ng_list = np.linspace(-2, 2, 220)
transmon.plot_evals_vs_paramvals('ng', ng_list, evals_count=5, subtract_ground=False);
# Out:
# Spectral data:   0%|          | 0/220 [00:00<?, ?it/s]

# %%
evals, evecs = transmon.eigensys()

# %%
transmon.plot_n_wavefunction(esys=None, which=1, mode='real');

# %%
transmon.plot_phi_wavefunction(esys=None, which=[0,1,2,3,4], mode='real');

# %% [markdown]
# # ALternative

# %%
transmon = scq.Transmon.create()
# Out:
# ...
# Output()

# %%
transmon = scq.Transmon(
    EJ=30.0,
    EC=3.75,
    ng=0.3,
    ncut=31
)

# %%
transmon.plot_matrixelements('n_operator', evals_count = 2)
# Out:
# (<Figure size 720x360 with 3 Axes>, (<Axes3DSubplot:>, <AxesSubplot:>))

# %%
transmon.plot_matelem_vs_paramvals('n_operator', 'EC', [5,10,15,20], select_elems=2)
# Out:
# Spectral data:   0%|          | 0/4 [00:00<?, ?it/s]
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$E_C$', ylabel='matrix element'>)

# %%
transmon.plot_n_wavefunction(which = 0)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='n', ylabel='Re $\\psi_j(n)$'>)
